# %% [markdown]
# # Example queries: `savings` (resstock_oedi)
#
# Auto-generated from `tests/query_snapshots/savings.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object

# %%
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "resstock_2024_amy2018_release_2",
    buildstock_type="resstock",
    db_schema="resstock_oedi_vu",
    skip_reports=True,
)

# %% [markdown]
# ## `savings_annual_upgrade1_electricity`
#
# Annual savings for upgrade 1, electricity, grouped by building type, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (5, 6)
#   geometry_building_type_recs  sample_count  units_count  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings
#                   Mobile Home           370 9.335161e+04                                    7.533442e+08                                   1.182440e+09                                  -4.290960e+08
# Multi-Family with 2 - 4 Units           467 1.178249e+05                                    8.531964e+08                                   9.854143e+08                                  -1.322179e+08
#    Multi-Family with 5+ Units          1872 4.723087e+05                                    3.061449e+09                                   3.070324e+09                                  -8.874926e+06
#        Single-Family Attached           662 1.670237e+05                                    1.339553e+09                                   1.803582e+09                                  -4.640286e+08
#        Single-Family Detached          5700 1.438119e+06                                    1.594169e+10                                   2.651883e+10                                  -1.057714e+10

# %% [markdown]
# ## `savings_ts_monthly_upgrade1_electricity`
#
# Monthly timeseries savings for upgrade 1, electricity, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (12, 7)
#  timestamp  sample_count  units_count rows_per_sample  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings
# 2018-01-01          9071 2.288628e+06            2976                                    2.468746e+09                                   4.873289e+09                                  -2.404543e+09
# 2018-02-01          9071 2.288628e+06            2688                                    2.279534e+09                                   4.846079e+09                                  -2.566545e+09
# 2018-03-01          9071 2.288628e+06            2976                                    1.793221e+09                                   2.670633e+09                                  -8.774119e+08
# 2018-04-01          9071 2.288628e+06            2880                                    1.536484e+09                                   2.119460e+09                                  -5.829760e+08
# 2018-05-01          9071 2.288628e+06            2976                                    1.426289e+09                                   1.586275e+09                                  -1.599855e+08

# %% [markdown]
# ## `savings_only_upgrade1_electricity`
#
# Savings-only annual output (no baseline / no upgrade columns) for upgrade 1, CO. Catches column-suppression bugs in the include_baseline / include_upgrade flags.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=False,
    include_upgrade=False,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (5, 4)
#   geometry_building_type_recs  sample_count  units_count  electricity.total.energy_consumption__savings
#                   Mobile Home           370 9.335161e+04                                  -4.290960e+08
# Annual savings for upgrade 1 covering both electricity and natural gas as enduses, grouped by building type, CO only. Pins the multi-fuel column-suffix shape across the baseline/upgrade/savings projection — every prior savings entry is electricity-only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (5, 9)
#   geometry_building_type_recs  sample_count  units_count  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings  natural_gas.total.energy_consumption__baseline  natural_gas.total.energy_consumption__upgrade  natural_gas.total.energy_consumption__savings
#                   Mobile Home           370 9.335161e+04                                    7.533442e+08                                   1.182440e+09                                  -4.290960e+08                                    1.275572e+09                                   2.384078e+08                                   1.037164e+09
# Multi-Family with 2 - 4 Units           467 1.178249e+05                                    8.531964e+08                                   9.854143e+08                                  -1.322179e+08                                    1.053705e+09                                   2.669896e+08                                   7.867155e+08
#    Multi-Family with 5+ Units          1872 4.723087e+05                                    3.061449e+09                                   3.070324e+09                                  -8.874926e+06                                    2.344413e+09                                   1.090802e+09                                   1.253611e+09
#        Single-Family Attached           662 1.670237e+05                                    1.339553e+09                                   1.803582e+09                                  -4.640286e+08                                    1.909135e+09                                   5.562419e+08                                   1.352893e+09
#        Single-Family Detached          5700 1.438119e+06                                    1.594169e+10                                   2.651883e+10                                  -1.057714e+10                                    3.121630e+10                                   6.236175e+09                                   2.498013e+10

# %% [markdown]
# ## `savings_ts_monthly_two_fuel`
#
# Monthly TS savings for upgrade 1 covering both electricity and natural gas, grouped by time, CO only. Mirrors savings_annual_two_fuel on the TS path — pins the multi-fuel column-suffix shape across baseline/upgrade/savings projections in the TS upgrade-pair flow. Comstock skips per UnsupportedQueryShape (TS upgrade-pair queries on comstock).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (12, 10)
#  timestamp  sample_count  units_count rows_per_sample  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings  natural_gas.total.energy_consumption__baseline  natural_gas.total.energy_consumption__upgrade  natural_gas.total.energy_consumption__savings
# 2018-01-01          9071 2.288628e+06            2976                                    2.468746e+09                                   4.873289e+09                                  -2.404543e+09                                    6.993579e+09                                   8.203957e+08                                   6.173183e+09
# 2018-02-01          9071 2.288628e+06            2688                                    2.279534e+09                                   4.846079e+09                                  -2.566545e+09                                    6.501400e+09                                   7.485840e+08                                   5.752816e+09
# 2018-03-01          9071 2.288628e+06            2976                                    1.793221e+09                                   2.670633e+09                                  -8.774119e+08                                    3.850777e+09                                   8.056951e+08                                   3.045082e+09
# 2018-04-01          9071 2.288628e+06            2880                                    1.536484e+09                                   2.119460e+09                                  -5.829760e+08                                    2.747712e+09                                   7.366309e+08                                   2.011081e+09
# 2018-05-01          9071 2.288628e+06            2976                                    1.426289e+09                                   1.586275e+09                                  -1.599855e+08                                    1.148455e+09                                   7.016875e+08                                   4.467670e+08
