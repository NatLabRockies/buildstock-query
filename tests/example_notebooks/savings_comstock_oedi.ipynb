# %% [markdown]
# # Example queries: `savings` (comstock_oedi)
#
# Auto-generated from `tests/query_snapshots/savings.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/comstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/comstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "comstock_amy2018_r2_2025",
    buildstock_type="comstock",
    db_schema="comstock_oedi_state_and_county",
    skip_reports=True,
    cache_folder=str(_CACHE),
)

# %% [markdown]
# ## `savings_annual_upgrade1_electricity`
#
# Annual savings for upgrade 1, electricity, grouped by building type, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (11, 6)
# comstock_building_type  sample_count  units_count  electricity.total.energy_consumption..kwh__baseline  electricity.total.energy_consumption..kwh__upgrade  electricity.total.energy_consumption..kwh__savings
#  FullServiceRestaurant         12018  4222.612917                                         1.073776e+09                                        1.067479e+09                                        6.297757e+06
#            LargeOffice            25     8.927070                                         7.665760e+06                                        6.772289e+06                                        8.934708e+05
#           MediumOffice          1823   603.917258                                         1.913053e+08                                        1.684458e+08                                        2.285951e+07
#             Outpatient           853  1387.428142                                         1.654028e+08                                        1.513751e+08                                        1.402775e+07
#          PrimarySchool           912  1108.926331                                         2.634047e+08                                        2.838699e+08                                       -2.046520e+07

# %% [markdown]
# ## `savings_ts_monthly_upgrade1_electricity`
#
# Monthly timeseries savings for upgrade 1, electricity, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (12, 7)
#  timestamp  sample_count  units_count rows_per_sample  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings
# 2018-01-01         78456 52826.632724            2976                                    5.271447e+08                                   6.278365e+08                                  -1.006918e+08
# 2018-02-01         78456 52826.632724            2688                                    4.853565e+08                                   6.315594e+08                                  -1.462029e+08
# 2018-03-01         78456 52826.632724            2976                                    4.687854e+08                                   4.721818e+08                                  -3.396395e+06
# 2018-04-01         78456 52826.632724            2880                                    4.425015e+08                                   4.255489e+08                                   1.695255e+07
# 2018-05-01         78456 52826.632724            2976                                    4.835680e+08                                   4.217814e+08                                   6.178660e+07

# %% [markdown]
# ## `savings_only_upgrade1_electricity`
#
# Savings-only annual output (no baseline / no upgrade columns) for upgrade 1, CO. Catches column-suppression bugs in the include_baseline / include_upgrade flags.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=False,
    include_upgrade=False,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape:
# %% [markdown]
# ## `savings_annual_two_fuel`
#
# Annual savings for upgrade 1 covering both electricity and natural gas as enduses, grouped by building type, CO only. Pins the multi-fuel column-suffix shape across the baseline/upgrade/savings projection — every prior savings entry is electricity-only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (11, 9)
# comstock_building_type  sample_count  units_count  electricity.total.energy_consumption..kwh__baseline  electricity.total.energy_consumption..kwh__upgrade  electricity.total.energy_consumption..kwh__savings  natural_gas.total.energy_consumption..kwh__baseline  natural_gas.total.energy_consumption..kwh__upgrade  natural_gas.total.energy_consumption..kwh__savings
#  FullServiceRestaurant         12018  4222.612917                                         1.073776e+09                                        1.067479e+09                                        6.297757e+06                                         1.110250e+09                                        9.065733e+08                                        2.036771e+08
#            LargeOffice            25     8.927070                                         7.665760e+06                                        6.772289e+06                                        8.934708e+05                                         1.560906e+06                                        4.943943e+04                                        1.511466e+06
#           MediumOffice          1823   603.917258                                         1.913053e+08                                        1.684458e+08                                        2.285951e+07                                         5.037715e+07                                        3.609832e+06                                        4.676732e+07
#             Outpatient           853  1387.428142                                         1.654028e+08                                        1.513751e+08                                        1.402775e+07                                         6.746017e+07                                        1.429535e+07                                        5.316482e+07
#          PrimarySchool           912  1108.926331                                         2.634047e+08                                        2.838699e+08                                       -2.046520e+07                                         2.520359e+08                                        5.203942e+07                                        1.999964e+08

# %% [markdown]
# ## `savings_ts_monthly_two_fuel`
#
# Monthly TS savings for upgrade 1 covering both electricity and natural gas, grouped by time, CO only. Mirrors savings_annual_two_fuel on the TS path — pins the multi-fuel column-suffix shape across baseline/upgrade/savings projections in the TS upgrade-pair flow. Comstock skips per UnsupportedQueryShape (TS upgrade-pair queries on comstock).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
# # shape: (12, 10)
#  timestamp  sample_count  units_count rows_per_sample  electricity.total.energy_consumption__baseline  electricity.total.energy_consumption__upgrade  electricity.total.energy_consumption__savings  natural_gas.total.energy_consumption__baseline  natural_gas.total.energy_consumption__upgrade  natural_gas.total.energy_consumption__savings
# 2018-01-01         78456 52826.632724            2976                                    5.271447e+08                                   6.278365e+08                                  -1.006918e+08                                    6.711535e+08                                   1.710371e+08                                   5.001164e+08
# 2018-02-01         78456 52826.632724            2688                                    4.853565e+08                                   6.315594e+08                                  -1.462029e+08                                    6.868279e+08                                   1.682375e+08                                   5.185904e+08
# 2018-03-01         78456 52826.632724            2976                                    4.687854e+08                                   4.721818e+08                                  -3.396395e+06                                    3.783491e+08                                   1.393015e+08                                   2.390476e+08
# 2018-04-01         78456 52826.632724            2880                                    4.425015e+08                                   4.255489e+08                                   1.695255e+07                                    2.820906e+08                                   1.292435e+08                                   1.528470e+08
# 2018-05-01         78456 52826.632724            2976                                    4.835680e+08                                   4.217814e+08                                   6.178660e+07                                    1.476172e+08                                   1.240756e+08                                   2.354158e+07
