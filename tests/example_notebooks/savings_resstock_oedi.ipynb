# %% [markdown]
# # Example queries: `savings` (resstock_oedi)
#
# Auto-generated from `tests/query_snapshots/savings.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/resstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/resstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "resstock_2024_amy2018_release_2",
    buildstock_type="resstock",
    db_schema="resstock_oedi_vu",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading resstock_2024_amy2018_release_2 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso

# %% [markdown]
# ## `savings_annual_upgrade1_electricity`
#
# Annual savings for upgrade 1, electricity, grouped by building type, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# 4                                   2.651883e+10
#
#    electricity.total.energy_consumption__savings
# 0                                  -4.290960e+08
# 1                                  -1.322179e+08
# 2                                  -8.874926e+06
# 3                                  -4.640286e+08
# 4                                  -1.057714e+10

# %% [markdown]
# ## `savings_ts_monthly_upgrade1_electricity`
#
# Monthly timeseries savings for upgrade 1, electricity, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#    timestamp  sample_count   units_count rows_per_sample  \
# 0 2018-01-01          9071  2.288628e+06            2976
# 1 2018-02-01          9071  2.288628e+06            2688
# 2 2018-03-01          9071  2.288628e+06            2976
# 3 2018-04-01          9071  2.288628e+06            2880
# 4 2018-05-01          9071  2.288628e+06            2976
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    2.468746e+09
# 1                                    2.279534e+09
# 2                                    1.793221e+09
# 3                                    1.536484e+09
# 4                                    1.426289e+09
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   4.873289e+09
# 1                                   4.846079e+09
# 2                                   2.670633e+09
# 3                                   2.119460e+09
# 4                                   1.586275e+09
#
#    electricity.total.energy_consumption__savings
# 0                                  -2.404543e+09
# 1                                  -2.566545e+09
# 2                                  -8.774119e+08
# 3                                  -5.829760e+08
# 4                                  -1.599855e+08

# %% [markdown]
# ## `savings_only_upgrade1_electricity`
#
# Savings-only annual output (no baseline / no upgrade columns) for upgrade 1, CO. Catches column-suppression bugs in the include_baseline / include_upgrade flags.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=False,
    include_upgrade=False,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__savings
# 0                                  -4.290960e+08
# 1                                  -1.322179e+08
# 2                                  -8.874926e+06
# 3                                  -4.640286e+08
# 4                                  -1.057714e+10

# %% [markdown]
# ## `savings_annual_upgrade1_quartiles`
#
# Annual upgrade 1 savings with quartiles, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
    get_quartiles=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# 4                                   2.651883e+10
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -4.290960e+08
# 1                                  -1.322179e+08
# 2                                  -8.874926e+06
# 3                                  -4.640286e+08
# 4                                  -1.057714e+10
#
#   electricity.total.energy_consumption__baseline__quartiles  \
# 0  [504.66838283656665, 708.6458476764334, 2284.0...
# 1  [383.3369597852667, 554.7835358360167, 2480.06...
# 2  [386.85381262733335, 591.4838490501168, 2104.5...
# 3  [438.7273920478167, 1151.476234706661, 3696.60...
# 4  [363.9942691539, 1658.622839394849, 4461.08342...
#
#   electricity.total.energy_consumption__baseline__nonzero_quartiles  \
# 0  [504.66838283656665, 708.6458476764334, 2284.0...
# 1  [383.3369597852667, 554.7835358360167, 2480.06...
# 2  [386.85381262733335, 591.4838490501168, 2104.5...
# 3  [438.7273920478167, 1151.476234706661, 3696.60...
# 4  [363.9942691539, 1658.622839394849, 4461.08342...
#
#   electricity.total.energy_consumption__upgrade__quartiles  \
# 0  [1397.0697915109834, 2103.3710706260385, 4573....
# 1  [1050.6597865674166, 1887.3776919091113, 3850....
# 2  [789.8265341141389, 1128.6301725024557, 2314.8...
# 3  [1431.945248861478, 2199.7914527127, 5398.2288...
# 4  [1714.4657605075, 3694.498979503505, 8892.0164...
#
#   electricity.total.energy_consumption__upgrade__nonzero_quartiles  \
# 0  [1397.0697915109834, 2103.3710706260385, 4573....
# 1  [1050.6597865674166, 1887.3776919091113, 3850....
# 2  [789.8265341141389, 1128.6301725024557, 2314.8...
# 3  [1431.945248861478, 2199.7914527127, 5398.2288...
# 4  [1714.4657605075, 3694.498979503505, 8892.0164...
#
#   electricity.total.energy_consumption__savings__quartiles  \
# 0  [-43592.563261697025, -17621.484236245204, -10...
# 1  [-26845.8961699159, -10362.993041289777, -5480...
# 2  [-16273.650384523158, -5576.705789482832, -278...
# 3  [-31844.22327170315, -16334.60916711898, -8403...
# 4  [-54198.219149089404, -29419.22298328922, -179...
#
#   electricity.total.energy_consumption__savings__nonzero_quartiles
# 0  [-43592.563261697025, -17621.484236245204, -10...
# 1  [-26845.8961699159, -10362.993041289777, -5480...
# 2  [-16273.650384523158, -5577.618543049157, -278...
# 3  [-31844.22327170315, -16334.60916711898, -8403...
# 4  [-54198.219149089404, -29419.22298328922, -179...

# %% [markdown]
# ## `savings_annual_two_fuel`
#
# Annual savings for upgrade 1 covering both electricity and natural gas as enduses, grouped by building type, CO only. Pins the multi-fuel column-suffix shape across the baseline/upgrade/savings projection — every prior savings entry is electricity-only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# 4                                   2.651883e+10
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -4.290960e+08
# 1                                  -1.322179e+08
# 2                                  -8.874926e+06
# 3                                  -4.640286e+08
# 4                                  -1.057714e+10
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.275572e+09
# 1                                    1.053705e+09
# 2                                    2.344413e+09
# 3                                    1.909135e+09
# 4                                    3.121630e+10
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   2.384078e+08
# 1                                   2.669896e+08
# 2                                   1.090802e+09
# 3                                   5.562419e+08
# 4                                   6.236175e+09
#
#    natural_gas.total.energy_consumption__savings
# 0                                   1.037164e+09
# 1                                   7.867155e+08
# 2                                   1.253611e+09
# 3                                   1.352893e+09
# 4                                   2.498013e+10

# %% [markdown]
# ## `savings_ts_monthly_two_fuel`
#
# Monthly TS savings for upgrade 1 covering both electricity and natural gas, grouped by time, CO only. Mirrors savings_annual_two_fuel on the TS path — pins the multi-fuel column-suffix shape across baseline/upgrade/savings projections in the TS upgrade-pair flow. Comstock skips per UnsupportedQueryShape (TS upgrade-pair queries on comstock).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#    timestamp  sample_count   units_count rows_per_sample  \
# 0 2018-01-01          9071  2.288628e+06            2976
# 1 2018-02-01          9071  2.288628e+06            2688
# 2 2018-03-01          9071  2.288628e+06            2976
# 3 2018-04-01          9071  2.288628e+06            2880
# 4 2018-05-01          9071  2.288628e+06            2976
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    2.468746e+09
# 1                                    2.279534e+09
# 2                                    1.793221e+09
# 3                                    1.536484e+09
# 4                                    1.426289e+09
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   4.873289e+09
# 1                                   4.846079e+09
# 2                                   2.670633e+09
# 3                                   2.119460e+09
# 4                                   1.586275e+09
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -2.404543e+09
# 1                                  -2.566545e+09
# 2                                  -8.774119e+08
# 3                                  -5.829760e+08
# 4                                  -1.599855e+08
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    6.993579e+09
# 1                                    6.501400e+09
# 2                                    3.850777e+09
# 3                                    2.747712e+09
# 4                                    1.148455e+09
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   8.203957e+08
# 1                                   7.485840e+08
# 2                                   8.056951e+08
# 3                                   7.366309e+08
# 4                                   7.016875e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   6.173183e+09
# 1                                   5.752816e+09
# 2                                   3.045082e+09
# 3                                   2.011081e+09
# 4                                   4.467670e+08
