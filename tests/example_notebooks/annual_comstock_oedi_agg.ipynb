# %% [markdown]
# # Example queries: `annual` (comstock_oedi_agg)
#
# Auto-generated from `tests/query_snapshots/annual.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/comstock_oedi_agg_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/comstock_oedi_agg_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "comstock_amy2018_r2_2025",
    buildstock_type="comstock",
    db_schema="comstock_oedi_agg_state_and_county",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading comstock_amy2018_r2_2025 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso

# %% [markdown]
# ## `annual_totals_overall`
#
# Annual electricity + natural gas totals restricted to CO.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count  electricity.total.energy_consumption..kwh  \
# 0         25743  84415.71204                               1.600424e+10
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.829994e+09

# %% [markdown]
# ## `annual_totals_by_building_type`
#
# Annual totals grouped by building type, CO only. Two variants confirm that omitting annual_only (default True) matches passing annual_only=True explicitly.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08

# %% [markdown]
# ## `annual_electricity_by_vintage_sort`
#
# Annual electricity grouped by vintage with sort, limit 5, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['vintage'],
    restrict=[('state', ['CO'])],
    sort=True,
    limit=5,
)
result.head() if hasattr(result, 'head') else result
# Out:
#         vintage  sample_count   units_count  \
# 0  1946 to 1959          2412  11466.085224
# 1  1960 to 1969          2408   5032.258720
# 2  1970 to 1979          3825  16714.165078
# 3  1980 to 1989          4159  11994.992091
# 4  1990 to 1999          3514   9542.647650
#
#    electricity.total.energy_consumption..kwh
# 0                               1.414138e+09
# 1                               1.407104e+09
# 2                               2.386718e+09
# 3                               2.733411e+09
# 4                               2.119967e+09

# %% [markdown]
# ## `annual_electricity_by_vintage_nosort`
#
# Annual electricity by vintage with sort=false + limit. Hits the no-ORDER-BY branch which existing entries never exercise. Marked nondeterministic because LIMIT without ORDER BY makes Trino free to return any 5 rows; only SQL shape is meaningful.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['vintage'],
    restrict=[('state', ['CO'])],
    sort=False,
    limit=5,
)
result.head() if hasattr(result, 'head') else result
# Out:
#         vintage  sample_count   units_count  \
# 0  1990 to 1999          3514   9542.647650
# 1  1970 to 1979          3825  16714.165078
# 2  1946 to 1959          2412  11466.085224
# 3  2000 to 2012          5146  15024.570443
# 4   Before 1946          3147  12367.244061
#
#    electricity.total.energy_consumption..kwh
# 0                               2.119967e+09
# 1                               2.386718e+09
# 2                               1.414138e+09
# 3                               2.911923e+09
# 4                               1.473168e+09

# %% [markdown]
# ## `annual_nonzero_count_natural_gas`
#
# Annual natural gas with nonzero_units_count requested, CO only.

# %%
result = bsq.query(
    enduses=['out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    get_nonzero_count=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    natural_gas.total.energy_consumption..kwh  \
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08
#
#    natural_gas.total.energy_consumption..kwh__nonzero_units_count
# 0                                        4556.431396
# 1                                         152.003100
# 2                                        3317.336942
# 3                                         593.598590
# 4                                        1873.838356

# %% [markdown]
# ## `annual_baseline_quartiles`
#
# Annual baseline (upgrade=0) electricity with get_quartiles=true. Hits the quartile branch on the upgrade-0 path where there is no upgrade-table join — the existing quartile coverage is upgrade=1 only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    get_quartiles=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09
#
#   electricity.total.energy_consumption..kwh__upgrade__quartiles  \
# 0  [41527.777777777774, 68033.16825396825, 125813...
# 1  [2381197.222222222, 2381197.222222222, 3056711...
# 2  [31405.55555555556, 34617.59259259259, 75354.4...
# 3  [46488.88888888889, 174026.22222222228, 479723...
# 4  [23244.444444444445, 106799.56111111114, 20632...
#
#   electricity.total.energy_consumption..kwh__upgrade__nonzero_quartiles
# 0  [41527.777777777774, 68033.16825396825, 125813...
# 1  [2381197.222222222, 2381197.222222222, 3056711...
# 2  [31405.55555555556, 34617.59259259259, 75354.4...
# 3  [46488.88888888889, 174026.22222222228, 479723...
# 4  [23244.444444444445, 106799.56111111114, 20632...

# %% [markdown]
# ## `annual_agg_func_mean`
#
# Annual electricity with agg_func='mean'. Pins the non-sum aggregation branch (no weight multiplication, AVG instead of SUM).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    agg_func='mean',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh__mean
# 0                                     4.378619e+05
# 1                                     8.505093e+06
# 2                                     1.324135e+06
# 3                                     2.610082e+06
# 4                                     6.348719e+05

# %% [markdown]
# ## `annual_agg_func_max`
#
# Annual electricity with agg_func='max'. Pins the MAX() aggregation branch.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    agg_func='max',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh__max
# 0                                    1.027759e+07
# 1                                    2.291753e+07
# 2                                    1.785975e+07
# 3                                    1.731915e+07
# 4                                    2.164978e+06

# %% [markdown]
# ## `annual_agg_func_min`
#
# Annual electricity with agg_func='min'. Pins the MIN() aggregation branch.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    agg_func='min',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh__min
# 0                                    4.152778e+04
# 1                                    2.381197e+06
# 2                                    3.140556e+04
# 3                                    4.648889e+04
# 4                                    2.324444e+04

# %% [markdown]
# ## `annual_with_extra_weight_sqft`
#
# Annual electricity with weights=[$SQFT_COL] — resstock 'in.sqft', comstock 'in.sqft..ft2'. Pins the SQL shape where the user supplies an explicit additional weight column on top of the default sample_weight; Athena gets `electricity * sample_weight * sqft`. Internally exercised by utility queries (eiaid_weights.weight); no other entry covers user-supplied weights directly.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    weights=['in.sqft..ft2'],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count   units_count  \
# 0  FullServiceRestaurant          2526  2.209403e+07
# 1               Hospital            63  3.277131e+07
# 2             LargeHotel          1460  8.083577e+07
# 3            LargeOffice           866  1.379344e+08
# 4           MediumOffice          2351  1.152651e+08
#
#    electricity.total.energy_consumption..kwh
# 0                               9.751824e+12
# 1                               2.972770e+14
# 2                               2.137382e+14
# 3                               5.365034e+14
# 4                               9.116622e+13

# %% [markdown]
# ## `annual_agg_func_arbitrary`
#
# Annual electricity with agg_func='arbitrary'. Pins the ARBITRARY() (Athena's any-value) aggregation branch. Marked nondeterministic because arbitrary() picks any group value per row; only SQL shape is meaningful.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    agg_func='arbitrary',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh__arbitrary
# 0                                       2.077111e+05
# 1                                       5.522081e+06
# 2                                       2.363053e+06
# 3                                       1.344592e+06
# 4                                       3.152778e+05
