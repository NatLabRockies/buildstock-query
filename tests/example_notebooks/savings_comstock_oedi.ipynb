# %% [markdown]
# # Example queries: `savings` (comstock_oedi)
#
# Auto-generated from `tests/query_snapshots/savings.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/comstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/comstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "comstock_amy2018_r2_2025",
    buildstock_type="comstock",
    db_schema="comstock_oedi_state_and_county",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading comstock_amy2018_r2_2025 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso

# %% [markdown]
# ## `savings_annual_upgrade1_electricity`
#
# Annual savings for upgrade 1, electricity, grouped by building type, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07

# %% [markdown]
# ## `savings_ts_monthly_upgrade1_electricity`
#
# Monthly timeseries savings for upgrade 1, electricity, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#    timestamp  sample_count   units_count rows_per_sample  \
# 0 2018-01-01         78456  52826.632724            2976
# 1 2018-02-01         78456  52826.632724            2688
# 2 2018-03-01         78456  52826.632724            2976
# 3 2018-04-01         78456  52826.632724            2880
# 4 2018-05-01         78456  52826.632724            2976
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    5.271447e+08
# 1                                    4.853565e+08
# 2                                    4.687854e+08
# 3                                    4.425015e+08
# 4                                    4.835680e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   6.278365e+08
# 1                                   6.315594e+08
# 2                                   4.721818e+08
# 3                                   4.255489e+08
# 4                                   4.217814e+08
#
#    electricity.total.energy_consumption__savings
# 0                                  -1.006918e+08
# 1                                  -1.462029e+08
# 2                                  -3.396395e+06
# 3                                   1.695255e+07
# 4                                   6.178660e+07

# %% [markdown]
# ## `savings_only_upgrade1_electricity`
#
# Savings-only annual output (no baseline / no upgrade columns) for upgrade 1, CO. Catches column-suppression bugs in the include_baseline / include_upgrade flags.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=False,
    include_upgrade=False,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07

# %% [markdown]
# ## `savings_annual_upgrade1_quartiles`
#
# Annual upgrade 1 savings with quartiles, CO only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
    get_quartiles=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07
#
#   electricity.total.energy_consumption..kwh__baseline__quartiles  \
# 0  [41527.777777777774, 68111.11111111111, 123230...
# 1  [290294.44444444444, 290294.44444444444, 29029...
# 2  [23244.444444444445, 43802.777777777774, 77173...
# 3  [23533.333333333332, 27461.111111111113, 28525...
# 4  [58205.555555555555, 58205.555555555555, 79933...
#
#   electricity.total.energy_consumption..kwh__baseline__nonzero_quartiles  \
# 0  [41527.777777777774, 68111.11111111111, 123230...
# 1  [290294.44444444444, 290294.44444444444, 29029...
# 2  [23244.444444444445, 43802.777777777774, 77173...
# 3  [23533.333333333332, 27461.111111111113, 28525...
# 4  [58205.555555555555, 58205.555555555555, 79933...
#
#   electricity.total.energy_consumption..kwh__upgrade__quartiles  \
# 0  [44741.666666666664, 76900.0, 118011.160820242...
# 1  [265636.1111111111, 265636.1111111111, 265636....
# 2  [27197.222222222223, 50008.333333333336, 95193...
# 3  [23802.777777777777, 26408.333333333332, 31180...
# 4  [73297.22222222222, 90575.77777777778, 99996.0...
#
#   electricity.total.energy_consumption..kwh__upgrade__nonzero_quartiles  \
# 0  [44741.666666666664, 76900.0, 118011.160820242...
# 1  [265636.1111111111, 265636.1111111111, 265636....
# 2  [27197.222222222223, 50008.333333333336, 95193...
# 3  [23802.777777777777, 26408.333333333332, 31180...
# 4  [73297.22222222222, 90575.77777777778, 99996.0...
#
#   electricity.total.energy_consumption..kwh__savings__quartiles  \
# 0  [-376058.33333333326, -83319.54429004404, -392...
# 1  [24658.333333333314, 24658.333333333314, 24658...
# 2  [-58169.44444444444, -49713.888888888876, -171...
# 3  [-102230.55555555539, -15127.777777777752, -37...
# 4  [-216533.33333333334, -125705.55555555556, -94...
#
#   electricity.total.energy_consumption..kwh__savings__nonzero_quartiles
# 0  [-376058.33333333326, -83319.54429004404, -392...
# 1  [24658.333333333314, 24658.333333333314, 24658...
# 2  [-58169.44444444444, -49713.888888888876, -171...
# 3  [-102230.55555555539, -15127.777777777752, -37...
# 4  [-216533.33333333334, -125705.55555555556, -94...

# %% [markdown]
# ## `savings_annual_two_fuel`
#
# Annual savings for upgrade 1 covering both electricity and natural gas as enduses, grouped by building type, CO only. Pins the multi-fuel column-suffix shape across the baseline/upgrade/savings projection — every prior savings entry is electricity-only.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    upgrade_id='1',
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.110250e+09
# 1                                       1.560906e+06
# 2                                       5.037715e+07
# 3                                       6.746017e+07
# 4                                       2.520359e+08
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       9.065733e+08
# 1                                       4.943943e+04
# 2                                       3.609832e+06
# 3                                       1.429535e+07
# 4                                       5.203942e+07
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.036771e+08
# 1                                       1.511466e+06
# 2                                       4.676732e+07
# 3                                       5.316482e+07
# 4                                       1.999964e+08

# %% [markdown]
# ## `savings_ts_monthly_two_fuel`
#
# Monthly TS savings for upgrade 1 covering both electricity and natural gas, grouped by time, CO only. Mirrors savings_annual_two_fuel on the TS path — pins the multi-fuel column-suffix shape across baseline/upgrade/savings projections in the TS upgrade-pair flow. Comstock skips per UnsupportedQueryShape (TS upgrade-pair queries on comstock).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['time'],
    restrict=[('state', ['CO'])],
    include_baseline=True,
    include_upgrade=True,
    include_savings=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#    timestamp  sample_count   units_count rows_per_sample  \
# 0 2018-01-01         78456  52826.632724            2976
# 1 2018-02-01         78456  52826.632724            2688
# 2 2018-03-01         78456  52826.632724            2976
# 3 2018-04-01         78456  52826.632724            2880
# 4 2018-05-01         78456  52826.632724            2976
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    5.271447e+08
# 1                                    4.853565e+08
# 2                                    4.687854e+08
# 3                                    4.425015e+08
# 4                                    4.835680e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   6.278365e+08
# 1                                   6.315594e+08
# 2                                   4.721818e+08
# 3                                   4.255489e+08
# 4                                   4.217814e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -1.006918e+08
# 1                                  -1.462029e+08
# 2                                  -3.396395e+06
# 3                                   1.695255e+07
# 4                                   6.178660e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    6.711535e+08
# 1                                    6.868279e+08
# 2                                    3.783491e+08
# 3                                    2.820906e+08
# 4                                    1.476172e+08
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.710371e+08
# 1                                   1.682375e+08
# 2                                   1.393015e+08
# 3                                   1.292435e+08
# 4                                   1.240756e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   5.001164e+08
# 1                                   5.185904e+08
# 2                                   2.390476e+08
# 3                                   1.528470e+08
# 4                                   2.354158e+07
