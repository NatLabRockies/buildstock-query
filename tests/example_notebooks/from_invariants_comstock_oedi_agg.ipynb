# %% [markdown]
# # Example queries: `from_invariants` (comstock_oedi_agg)
#
# Auto-generated from `tests/query_snapshots/from_invariants.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
from buildstock_query.schema.utilities import MappedColumn
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/comstock_oedi_agg_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/comstock_oedi_agg_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "comstock_amy2018_r2_2025",
    buildstock_type="comstock",
    db_schema="comstock_oedi_agg_state_and_county",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading comstock_amy2018_r2_2025 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso
# INFO:botocore.tokens:SSO Token refresh succeeded

# %% [markdown]
# ## `query__comstock_oedi_agg__v5`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count  electricity.total.energy_consumption..kwh  \
# 0         25743  84415.71204                               1.600424e+10
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.829994e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__by_comstock_building_type__v6`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__baseline__by_comstock_building_type__v31`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          3640  6481.401989
# 1               Hospital           156   384.224912
# 2             LargeHotel          1896  3836.361595
# 3            LargeOffice           987   920.591301
# 4           MediumOffice          3025  2903.093740
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.624013e+09
# 1                               2.033883e+09
# 2                               1.368301e+09
# 3                               1.641582e+09
# 4                               1.536703e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.564653e+09
# 1                               1.233206e+09
# 2                               1.092790e+09
# 3                               4.703962e+08
# 4                               4.469503e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__baseline__ts_year__by_comstock_building_type__v32`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          3640  6481.401989           35040
# 1               Hospital           156   384.224912           35040
# 2             LargeHotel          1896  3836.361595           35040
# 3            LargeOffice           987   920.591301           35040
# 4           MediumOffice          3025  2903.093740           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.624013e+09                          1.565700e+09
# 1                          2.033883e+09                          1.234031e+09
# 2                          1.368301e+09                          1.093520e+09
# 3                          1.641582e+09                          4.707112e+08
# 4                          1.536703e+09                          4.472496e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__baseline__ts_month__by_comstock_building_type_time__v33`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          3640  6481.401989
# 1  FullServiceRestaurant 2018-02-01          3640  6481.401989
# 2  FullServiceRestaurant 2018-03-01          3640  6481.401989
# 3  FullServiceRestaurant 2018-04-01          3640  6481.401989
# 4  FullServiceRestaurant 2018-05-01          3640  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.364880e+08
# 1            2688                          1.256194e+08
# 2            2976                          1.284009e+08
# 3            2880                          1.239559e+08
# 4            2976                          1.355445e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.679840e+08
# 1                          1.533654e+08
# 2                          1.389757e+08
# 3                          1.242156e+08
# 4                          1.118380e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v34`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          3640  6481.401989
# 1               Hospital           156   384.224912
# 2             LargeHotel          1896  3836.361595
# 3            LargeOffice           987   920.591301
# 4           MediumOffice          3025  2903.093740
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.624013e+09
# 1                                       2.033883e+09
# 2                                       1.368301e+09
# 3                                       1.641582e+09
# 4                                       1.536703e+09
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.591728e+09
# 1                                       2.032565e+09
# 2                                       1.368301e+09
# 3                                       1.640506e+09
# 4                                       1.505989e+09
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_year__by_comstock_building_type__v35`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          3640  6481.401989           35040
# 1               Hospital           156   384.224912           35040
# 2             LargeHotel          1896  3836.361595           35040
# 3            LargeOffice           987   920.591301           35040
# 4           MediumOffice          3025  2903.093740           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.624013e+09
# 1                                    2.033883e+09
# 2                                    1.368301e+09
# 3                                    1.641582e+09
# 4                                    1.536703e+09
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.591728e+09
# 1                                   2.032565e+09
# 2                                   1.368301e+09
# 3                                   1.640506e+09
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_month__by_comstock_building_type_time__v36`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          3640  6481.401989
# 1  FullServiceRestaurant 2018-02-01          3640  6481.401989
# 2  FullServiceRestaurant 2018-03-01          3640  6481.401989
# 3  FullServiceRestaurant 2018-04-01          3640  6481.401989
# 4  FullServiceRestaurant 2018-05-01          3640  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.364880e+08
# 1            2688                                    1.256194e+08
# 2            2976                                    1.284009e+08
# 3            2880                                    1.239559e+08
# 4            2976                                    1.355445e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.502726e+08
# 1                                   1.421485e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v37`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2986  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            24    17.120897
# 3           MediumOffice           673   733.337073
# 4             Outpatient           535  1789.764634
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.457327e+09
# 1                                       7.905386e+06
# 2                                       8.724252e+06
# 3                                       2.375055e+08
# 4                                       2.302601e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.425042e+09
# 1                                       6.587452e+06
# 2                                       7.648615e+06
# 3                                       2.067922e+08
# 4                                       2.060655e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_comstock_building_type__v38`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          2986  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            24    17.120897           35040
# 3           MediumOffice           673   733.337073           35040
# 4             Outpatient           535  1789.764634           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.457326e+09
# 1                                    7.905383e+06
# 2                                    8.724251e+06
# 3                                    2.375054e+08
# 4                                    2.302599e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.425041e+09
# 1                                   6.587449e+06
# 2                                   7.648613e+06
# 3                                   2.067922e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_comstock_building_type_time__v39`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          2986  6046.539978
# 1  FullServiceRestaurant 2018-02-01          2986  6046.539978
# 2  FullServiceRestaurant 2018-03-01          2986  6046.539978
# 3  FullServiceRestaurant 2018-04-01          2986  6046.539978
# 4  FullServiceRestaurant 2018-05-01          2986  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.209618e+08
# 1            2688                                    1.112006e+08
# 2            2976                                    1.150298e+08
# 3            2880                                    1.113886e+08
# 4            2976                                    1.224167e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.347465e+08
# 1                                   1.277297e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v40`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2986  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            24    17.120897
# 3           MediumOffice           673   733.337073
# 4             Outpatient           527  1780.638615
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.457327e+09
# 1                                       7.905386e+06
# 2                                       8.724252e+06
# 3                                       2.375055e+08
# 4                                       2.239151e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.425042e+09
# 1                                       6.587452e+06
# 2                                       7.648615e+06
# 3                                       2.067922e+08
# 4                                       2.003235e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_comstock_building_type__v41`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          2986  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            24    17.120897           35040
# 3           MediumOffice           673   733.337073           35040
# 4             Outpatient           527  1780.638615           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.457326e+09
# 1                                    7.905383e+06
# 2                                    8.724251e+06
# 3                                    2.375054e+08
# 4                                    2.239149e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.425041e+09
# 1                                   6.587449e+06
# 2                                   7.648613e+06
# 3                                   2.067922e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_comstock_building_type_time__v42`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          2986  6046.539978
# 1  FullServiceRestaurant 2018-02-01          2986  6046.539978
# 2  FullServiceRestaurant 2018-03-01          2986  6046.539978
# 3  FullServiceRestaurant 2018-04-01          2986  6046.539978
# 4  FullServiceRestaurant 2018-05-01          2986  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.209618e+08
# 1            2688                                    1.112006e+08
# 2            2976                                    1.150298e+08
# 3            2880                                    1.113886e+08
# 4            2976                                    1.224167e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.347465e+08
# 1                                   1.277297e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v55`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          3640  6481.401989
# 1               Hospital           156   384.224912
# 2             LargeHotel          1896  3836.361595
# 3            LargeOffice           987   920.591301
# 4           MediumOffice          3025  2903.093740
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.591728e+09
# 1                               2.032565e+09
# 2                               1.368301e+09
# 3                               1.640506e+09
# 4                               1.505989e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.324389e+09
# 1                               1.232085e+09
# 2                               1.092790e+09
# 3                               4.686625e+08
# 4                               3.955813e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_year__by_comstock_building_type__v56`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          3640  6481.401989           35040
# 1               Hospital           156   384.224912           35040
# 2             LargeHotel          1896  3836.361595           35040
# 3            LargeOffice           987   920.591301           35040
# 4           MediumOffice          3025  2903.093740           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.591728e+09                          1.325275e+09
# 1                          2.032565e+09                          1.232910e+09
# 2                          1.368301e+09                          1.093520e+09
# 3                          1.640506e+09                          4.689763e+08
# 4                          1.505990e+09                          3.958463e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_month__by_comstock_building_type_time__v57`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          3640  6481.401989
# 1  FullServiceRestaurant 2018-02-01          3640  6481.401989
# 2  FullServiceRestaurant 2018-03-01          3640  6481.401989
# 3  FullServiceRestaurant 2018-04-01          3640  6481.401989
# 4  FullServiceRestaurant 2018-05-01          3640  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.502726e+08
# 1            2688                          1.421485e+08
# 2            2976                          1.255408e+08
# 3            2880                          1.181610e+08
# 4            2976                          1.243772e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.204465e+08
# 1                          1.096406e+08
# 2                          1.149062e+08
# 3                          1.087103e+08
# 4                          1.084215e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v58`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2986  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            24    17.120897
# 3           MediumOffice           673   733.337073
# 4             Outpatient           535  1789.764634
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.425042e+09
# 1                               6.587452e+06
# 2                               7.648615e+06
# 3                               2.067922e+08
# 4                               2.060655e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.220440e+09
# 1                               1.304981e+06
# 2                               5.486811e+04
# 3                               4.402240e+06
# 4                               1.987862e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_comstock_building_type__v59`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          2986  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            24    17.120897           35040
# 3           MediumOffice           673   733.337073           35040
# 4             Outpatient           535  1789.764634           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.425041e+09                          1.221256e+09
# 1                          6.587449e+06                          1.305859e+06
# 2                          7.648613e+06                          5.491002e+04
# 3                          2.067922e+08                          4.405337e+06
# 4                          2.060657e+08                          1.989197e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_comstock_building_type_time__v60`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          2986  6046.539978
# 1  FullServiceRestaurant 2018-02-01          2986  6046.539978
# 2  FullServiceRestaurant 2018-03-01          2986  6046.539978
# 3  FullServiceRestaurant 2018-04-01          2986  6046.539978
# 4  FullServiceRestaurant 2018-05-01          2986  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.347465e+08
# 1            2688                          1.277297e+08
# 2            2976                          1.121696e+08
# 3            2880                          1.055937e+08
# 4            2976                          1.112494e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.099475e+08
# 1                          9.977619e+07
# 2                          1.056390e+08
# 3                          1.003005e+08
# 4                          1.006373e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__by_comstock_building_type__v68`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__by_state__v69`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state'],
    restrict=[('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  sample_count   units_count  electricity.total.energy_consumption..kwh
# 0    CO         25743  84415.712040                               1.600424e+10
# 1    WY          8469  11666.235991                               1.768901e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__by_comstock_building_type__v72`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    avoid=[('comstock_building_type', ['Warehouse'])],
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__ts__by_state_time__v77`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state           timestamp  sample_count  units_count  \
# 0    CO 2018-01-01 00:15:00         25743  84415.71204
# 1    CO 2018-01-01 00:30:00         25743  84415.71204
# 2    CO 2018-01-01 00:45:00         25743  84415.71204
# 3    CO 2018-01-01 01:00:00         25743  84415.71204
# 4    CO 2018-01-01 01:15:00         25743  84415.71204
#
#    electricity.total.energy_consumption
# 0                         558329.416935
# 1                         556124.833268
# 2                         552236.206143
# 3                         550257.671238
# 4                         542227.004333

# %% [markdown]
# ## `query__comstock_oedi_agg__ts_month__by_state_time__v78`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state  timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01         25743  84415.71204            2976
# 1    CO 2018-02-01         25743  84415.71204            2688
# 2    CO 2018-03-01         25743  84415.71204            2976
# 3    CO 2018-04-01         25743  84415.71204            2880
# 4    CO 2018-05-01         25743  84415.71204            2976
#
#    electricity.total.energy_consumption
# 0                          1.385482e+09
# 1                          1.280966e+09
# 2                          1.237644e+09
# 3                          1.171385e+09
# 4                          1.289014e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__ts_hour__by_state_time__v81`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='hour',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state           timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01 00:00:00         25743  84415.71204               4
# 1    CO 2018-01-01 01:00:00         25743  84415.71204               4
# 2    CO 2018-01-01 02:00:00         25743  84415.71204               4
# 3    CO 2018-01-01 03:00:00         25743  84415.71204               4
# 4    CO 2018-01-01 04:00:00         25743  84415.71204               4
#
#    electricity.total.energy_consumption
# 0                          2.216948e+06
# 1                          2.177930e+06
# 2                          1.874028e+06
# 3                          1.832707e+06
# 4                          1.820178e+06

# %% [markdown]
# ## `query__comstock_oedi_agg__ts_day__by_state_time__v84`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='day',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state  timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01         25743  84415.71204              96
# 1    CO 2018-01-02         25743  84415.71204              96
# 2    CO 2018-01-03         25743  84415.71204              96
# 3    CO 2018-01-04         25743  84415.71204              96
# 4    CO 2018-01-05         25743  84415.71204              96
#
#    electricity.total.energy_consumption
# 0                          5.631904e+07
# 1                          5.220220e+07
# 2                          4.810277e+07
# 3                          4.638417e+07
# 4                          4.562267e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v89`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v90`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=False,
    include_savings=True,
    include_upgrade=False,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__baseline__by_comstock_building_type__v97`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.073776e+09
# 1                               7.665760e+06
# 2                               1.913053e+08
# 3                               1.654028e+08
# 4                               2.634047e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.110250e+09
# 1                               1.560906e+06
# 2                               5.037715e+07
# 3                               6.746017e+07
# 4                               2.520359e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v98`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.067479e+09
# 1                               6.772289e+06
# 2                               1.684458e+08
# 3                               1.513751e+08
# 4                               2.838699e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.065733e+08
# 1                               4.943943e+04
# 2                               3.609832e+06
# 3                               1.429535e+07
# 4                               5.203942e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v99`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v102`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           408  1387.428142
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
# ...

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v105`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant           930  1823.927061
# 1               Hospital             5     7.105761
# 2            LargeOffice             2     8.193827
# 3           MediumOffice           146   129.419815
# 4             Outpatient           127   402.336491
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       3.835508e+08
# 1                                       7.905386e+06
# 2                                       1.058493e+06
# 3                                       4.620015e+07
# 4                                       6.485727e+07
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       3.575633e+08
# 1                                       6.587452e+06
# 2                                       8.763264e+05
# 3                                       3.834644e+07
# 4                                       5.469037e+07
# ...

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v130`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    49971  G0800140    CO
# 1    50033  G0800140    CO
# 2    50614  G0800140    CO
# 3    50850  G0800140    CO
# 4    50887  G0800140    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v131`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    48728  G0800310    CO
# 1    48775  G0800310    CO
# 2    49284  G0800310    CO
# 3    49975  G0800310    CO
# 4    50032  G0800310    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v132`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    46369  G0800190    CO
# 1    47712  G0800190    CO
# 2    48180  G0800190    CO
# 3    48236  G0800190    CO
# 4    48345  G0800190    CO

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v133`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2056  4222.612917
# 1            LargeOffice            22     8.927070
# 2           MediumOffice           527   603.917258
# 3             Outpatient           400  1378.302123
# 4          PrimarySchool           475  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.067479e+09
# 1                               6.772289e+06
# 2                               1.684458e+08
# 3                               1.456331e+08
# 4                               2.838699e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.065733e+08
# 1                               4.943943e+04
# 2                               3.609832e+06
# 3                               1.386505e+07
# 4                               5.203942e+07

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v134`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    49892  G0800550    CO
# 1    50121  G0800550    CO
# 2    50165  G0800550    CO
# 3    50716  G0800550    CO
# 4    50945  G0800550    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v135`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    11617  G3500490    NM
# 1    11628  G3500490    NM
# 2    12742  G3500490    NM
# 3    12875  G3500490    NM
# 4    12929  G3500490    NM

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v136`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0     8275  G3500290    NM
# 1     8317  G3500290    NM
# 2     8849  G3500290    NM
# 3     8870  G3500290    NM
# 4    48662  G0800310    CO

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v137`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2986  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            24    17.120897
# 3           MediumOffice           673   733.337073
# 4             Outpatient           527  1780.638615
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.425042e+09
# 1                               6.587452e+06
# 2                               7.648615e+06
# 3                               2.067922e+08
# 4                               2.003235e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.220440e+09
# 1                               1.304981e+06
# 2                               5.486811e+04
# 3                               4.402240e+06
# 4                               1.944832e+07

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v138`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['NM'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0     8187  G3500250    NM
# 1     8188  G3500250    NM
# 2     8847  G3500250    NM
# 3    51075  G3500510    NM
# 4    51934  G3500510    NM

# %% [markdown]
# ## `get_building_ids__comstock_oedi_agg__v141`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi_agg).

# %%
result = bsq.get_building_ids(restrict=[('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id    county state
# 0    50900  G0800350    CO
# 1    50901  G0800350    CO
# 2    50902  G0800350    CO
# 3    50903  G0800350    CO
# 4    50904  G0800350    CO

# %% [markdown]
# ## `query__comstock_oedi_agg__by_comstock_building_type__v144`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.natural_gas.total.energy_consumption..kwh'],
    get_nonzero_count=True,
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    natural_gas.total.energy_consumption..kwh  \
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08
#
#    natural_gas.total.energy_consumption..kwh__nonzero_units_count
# 0                                        4556.431396
# 1                                         152.003100
# 2                                        3317.336942
# 3                                         593.598590
# 4                                        1873.838356

# %% [markdown]
# ## `query__comstock_oedi_agg__by_vintage__v147`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['vintage'],
    limit=5,
    restrict=[('state', ['CO'])],
    sort=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#         vintage  sample_count   units_count  \
# 0  1946 to 1959          2412  11466.085224
# 1  1960 to 1969          2408   5032.258720
# 2  1970 to 1979          3825  16714.165078
# 3  1980 to 1989          4159  11994.992091
# 4  1990 to 1999          3514   9542.647650
#
#    electricity.total.energy_consumption..kwh
# 0                               1.414138e+09
# 1                               1.407104e+09
# 2                               2.386718e+09
# 3                               2.733411e+09
# 4                               2.119967e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__by_comstock_building_type__v150`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    agg_func='mean',
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          2526  4556.431396
# 1               Hospital            63   152.003100
# 2             LargeHotel          1460  3317.336942
# 3            LargeOffice           866   849.927533
# 4           MediumOffice          2351  2418.404703
#
#    electricity.total.energy_consumption..kwh__mean
# 0                                     4.378619e+05
# 1                                     8.505093e+06
# 2                                     1.324135e+06
# 3                                     2.610082e+06
# 4                                     6.348719e+05

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_comstock_building_type__v156`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          2056  4222.612917           35040
# 1            LargeOffice            22     8.927070           35040
# 2           MediumOffice           527   603.917258           35040
# 3             Outpatient           400  1378.302123           35040
# 4          PrimarySchool           475  1108.926331           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.067478e+09                          9.071796e+08
# 1                          6.772292e+06                          4.947173e+04
# 2                          1.684457e+08                          3.612400e+06
# 3                          1.456332e+08                          1.387436e+07
# 4                          2.838701e+08                          5.207440e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_comstock_building_type_time__v157`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          2056  4222.612917
# 1  FullServiceRestaurant 2018-02-01          2056  4222.612917
# 2  FullServiceRestaurant 2018-03-01          2056  4222.612917
# 3  FullServiceRestaurant 2018-04-01          2056  4222.612917
# 4  FullServiceRestaurant 2018-05-01          2056  4222.612917
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.041671e+08
# 1            2688                          1.016340e+08
# 2            2976                          8.463370e+07
# 3            2880                          7.864523e+07
# 4            2976                          8.022208e+07
#
#    natural_gas.total.energy_consumption
# 0                          8.183587e+07
# 1                          7.482833e+07
# 2                          7.862536e+07
# 3                          7.464483e+07
# 4                          7.459019e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_county__v158`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['county'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  sample_count  units_count  \
# 0  G0800010           403  4804.637602
# 1  G0800030           130   139.689194
# 2  G0800050           415  4862.682818
# 3  G0800070           115    95.758184
# 4  G0800090            39    15.683240
#
#    electricity.total.energy_consumption..kwh  \
# 0                               6.858618e+08
# 1                               1.195576e+07
# 2                               5.657102e+08
# 3                               8.205993e+06
# 4                               1.572804e+06
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.323744e+08
# 1                               3.039211e+06
# 2                               1.472686e+08
# 3                               2.562789e+06
# 4                               3.176032e+05

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_county__v159`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['county'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  sample_count  units_count rows_per_sample  \
# 0  G0800010           403  4804.637602           35040
# 1  G0800030           130   139.689194           35040
# 2  G0800050           415  4862.682818           35040
# 3  G0800070           115    95.758184           35040
# 4  G0800090            39    15.683240           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          6.858619e+08                          1.324627e+08
# 1                          1.195578e+07                          3.041263e+06
# 2                          5.657102e+08                          1.473664e+08
# 3                          8.206003e+06                          2.564515e+06
# 4                          1.572810e+06                          3.178172e+05

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_county_time__v160`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['county', 'time'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  timestamp  sample_count  units_count rows_per_sample  \
# 0  G0800010 2018-01-01           403  4804.637602            2976
# 1  G0800010 2018-02-01           403  4804.637602            2688
# 2  G0800010 2018-03-01           403  4804.637602            2976
# 3  G0800010 2018-04-01           403  4804.637602            2880
# 4  G0800010 2018-05-01           403  4804.637602            2976
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          7.060403e+07                          1.657152e+07
# 1                          7.149407e+07                          1.806266e+07
# 2                          5.379953e+07                          1.044328e+07
# 3                          4.894908e+07                          9.480886e+06
# 4                          4.882248e+07                          8.549346e+06

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__by_comstock_building_type__v173`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption..kwh - out.natural_gas.total.energy_consumption..kwh', table='baseline')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  elec_minus_gas
# 0  FullServiceRestaurant          3640  6481.401989    2.673392e+08
# 1               Hospital           156   384.224912    8.004801e+08
# 2             LargeHotel          1896  3836.361595    2.755110e+08
# 3            LargeOffice           987   920.591301    1.171844e+09
# 4           MediumOffice          3025  2903.093740    1.110408e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_year__by_comstock_building_type__v174`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          3640  6481.401989           35040
# 1               Hospital           156   384.224912           35040
# 2             LargeHotel          1896  3836.361595           35040
# 3            LargeOffice           987   920.591301           35040
# 4           MediumOffice          3025  2903.093740           35040
#
#    elec_minus_gas
# 0    2.664527e+08
# 1    7.996552e+08
# 2    2.747804e+08
# 3    1.171530e+09
# 4    1.110143e+09

# %% [markdown]
# ## `query__comstock_oedi_agg__u1__ts_month__by_comstock_building_type_time__v175`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          3640  6481.401989
# 1  FullServiceRestaurant 2018-02-01          3640  6481.401989
# 2  FullServiceRestaurant 2018-03-01          3640  6481.401989
# 3  FullServiceRestaurant 2018-04-01          3640  6481.401989
# 4  FullServiceRestaurant 2018-05-01          3640  6481.401989
#
#   rows_per_sample  elec_minus_gas
# 0            2976    2.982614e+07
# 1            2688    3.250791e+07
# 2            2976    1.063463e+07
# 3            2880    9.450730e+06
# 4            2976    1.595577e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__by_comstock_building_type__v176`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption..kwh - out.natural_gas.total.energy_consumption..kwh', table='baseline')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  elec_minus_gas
# 0  FullServiceRestaurant          2986  6046.539978    2.046022e+08
# 1               Hospital             5     7.105761    5.282471e+06
# 2            LargeOffice            24    17.120897    7.593747e+06
# 3           MediumOffice           673   733.337073    2.023900e+08
# 4             Outpatient           535  1789.764634    1.861868e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_year__by_comstock_building_type__v177`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant          2986  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            24    17.120897           35040
# 3           MediumOffice           673   733.337073           35040
# 4             Outpatient           535  1789.764634           35040
#
#    elec_minus_gas
# 0    2.037852e+08
# 1    5.281589e+06
# 2    7.593703e+06
# 3    2.023868e+08
# 4    1.861737e+08

# %% [markdown]
# ## `query__comstock_oedi_agg__applied__u1__ts_month__by_comstock_building_type_time__v178`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01          2986  6046.539978
# 1  FullServiceRestaurant 2018-02-01          2986  6046.539978
# 2  FullServiceRestaurant 2018-03-01          2986  6046.539978
# 3  FullServiceRestaurant 2018-04-01          2986  6046.539978
# 4  FullServiceRestaurant 2018-05-01          2986  6046.539978
#
#   rows_per_sample  elec_minus_gas
# 0            2976    2.479894e+07
# 1            2688    2.795347e+07
# 2            2976    6.530650e+06
# 3            2880    5.293182e+06
# 4            2976    1.061216e+07

# %% [markdown]
# ## `query__comstock_oedi_agg__v181`
#
# Auto-recorded from test_invariants (query, comstock_oedi_agg).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=[MappedColumn(bsq=bsq, name='simple_bldg_type', mapping_dict={'FullServiceRestaurant': 'Food', 'Hospital': 'Health', 'LargeHotel': 'Lodging', 'LargeOffice': 'Office', 'MediumOffice': 'Office', 'Outpatient': 'Health', 'PrimarySchool': 'School', 'QuickServiceRestaurant': 'Food', 'RetailStandalone': 'Retail', 'RetailStripmall': 'Retail', 'SecondarySchool': 'School', 'SmallHotel': 'Lodging', 'SmallOffice': 'Office', 'Warehouse': 'Warehouse'}, key=bsq._get_column('comstock_building_type'))],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   simple_bldg_type  sample_count   units_count  \
# 0             Food          3720   6735.091005
# 1           Health           868   2089.226424
# 2          Lodging          2537   4548.531762
# 3           Office          7161  22514.402048
# 4           Retail          5904  21431.873432
#
#    electricity.total.energy_consumption..kwh
# 0                               1.540008e+09
# 1                               1.990316e+09
# 2                               1.382815e+09
# 3                               3.921176e+09
# 4                               2.990783e+09
