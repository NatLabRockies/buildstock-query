# %% [markdown]
# # Example queries: `from_invariants` (resstock_oedi)
#
# Auto-generated from `tests/query_snapshots/from_invariants.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
from buildstock_query.schema.utilities import MappedColumn
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/resstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/resstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "resstock_2024_amy2018_release_2",
    buildstock_type="resstock",
    db_schema="resstock_oedi_vu",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading resstock_2024_amy2018_release_2 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso
# INFO:botocore.tokens:SSO Token refresh succeeded

# %% [markdown]
# ## `query__resstock_oedi__v1`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count   units_count  electricity.total.energy_consumption  \
# 0          9425  2.377943e+06                          2.259390e+10
#
#    natural_gas.total.energy_consumption
# 0                          3.795731e+10

# %% [markdown]
# ## `query__resstock_oedi__by_geometry_building_type_recs__v2`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           391  9.864994e+04
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 2     Multi-Family with 5+ Units          2001  5.048556e+05
# 3         Single-Family Attached           664  1.675283e+05
# 4         Single-Family Detached          5900  1.488580e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          7.898215e+08                          1.279629e+09
# 1                          8.547447e+08                          1.054712e+09
# 2                          3.249347e+09                          2.466138e+09
# 3                          1.345615e+09                          1.909135e+09
# 4                          1.635437e+10                          3.124770e+10

# %% [markdown]
# ## `query__resstock_oedi__baseline__by_geometry_building_type_recs__v7`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           541  1.364952e+05
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05
# 2     Multi-Family with 5+ Units          2104  5.308426e+05
# 3         Single-Family Attached           717  1.809003e+05
# 4         Single-Family Detached          6625  1.671498e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.068286e+09                          1.843788e+09
# 1                          9.969509e+08                          1.236648e+09
# 2                          3.432264e+09                          2.576012e+09
# 3                          1.476259e+09                          2.069592e+09
# 4                          1.850699e+10                          3.549858e+10

# %% [markdown]
# ## `query__resstock_oedi__baseline__ts_year__by_geometry_building_type_recs__v8`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           541  1.364952e+05           35040
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05           35040
# 2     Multi-Family with 5+ Units          2104  5.308426e+05           35040
# 3         Single-Family Attached           717  1.809003e+05           35040
# 4         Single-Family Detached          6625  1.671498e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.068285e+09                          1.843788e+09
# 1                          9.969480e+08                          1.236647e+09
# 2                          3.432237e+09                          2.576013e+09
# 3                          1.476253e+09                          2.069592e+09
# 4                          1.850697e+10                          3.549858e+10

# %% [markdown]
# ## `query__resstock_oedi__baseline__ts_month__by_geometry_building_type_recs_time__v9`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count    units_count  \
# 0                 Mobile Home 2018-01-01           541  136495.186553
# 1                 Mobile Home 2018-02-01           541  136495.186553
# 2                 Mobile Home 2018-03-01           541  136495.186553
# 3                 Mobile Home 2018-04-01           541  136495.186553
# 4                 Mobile Home 2018-05-01           541  136495.186553
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.112856e+08
# 1            2688                          1.029864e+08
# 2            2976                          9.250425e+07
# 3            2880                          8.207030e+07
# 4            2976                          7.726668e+07
#
#    natural_gas.total.energy_consumption
# 0                          3.065705e+08
# 1                          2.925406e+08
# 2                          1.892569e+08
# 3                          1.376606e+08
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v10`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           541  1.364952e+05
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05
# 2     Multi-Family with 5+ Units          2104  5.308426e+05
# 3         Single-Family Attached           717  1.809003e+05
# 4         Single-Family Detached          6625  1.671498e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.068286e+09
# 1                                    9.969509e+08
# 2                                    3.432264e+09
# 3                                    1.476259e+09
# 4                                    1.850699e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.709205e+09
# 1                                   1.138115e+09
# 2                                   3.418385e+09
# 3                                   1.953969e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_year__by_geometry_building_type_recs__v11`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           541  1.364952e+05           35040
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05           35040
# 2     Multi-Family with 5+ Units          2104  5.308426e+05           35040
# 3         Single-Family Attached           717  1.809003e+05           35040
# 4         Single-Family Detached          6625  1.671498e+06           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.068285e+09
# 1                                    9.969480e+08
# 2                                    3.432237e+09
# 3                                    1.476253e+09
# 4                                    1.850697e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.709202e+09
# 1                                   1.138111e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_month__by_geometry_building_type_recs_time__v12`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count    units_count  \
# 0                 Mobile Home 2018-01-01           541  136495.186553
# 1                 Mobile Home 2018-02-01           541  136495.186553
# 2                 Mobile Home 2018-03-01           541  136495.186553
# 3                 Mobile Home 2018-04-01           541  136495.186553
# 4                 Mobile Home 2018-05-01           541  136495.186553
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.112856e+08
# 1            2688                                    1.029864e+08
# 2            2976                                    9.250425e+07
# 3            2880                                    8.207030e+07
# 4            2976                                    7.726668e+07
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   2.248095e+08
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v13`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           512  1.291784e+05
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05
# 2     Multi-Family with 5+ Units          1973  4.977911e+05
# 3         Single-Family Attached           715  1.803957e+05
# 4         Single-Family Detached          6365  1.605900e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.020683e+09
# 1                                    9.954026e+08
# 2                                    3.242676e+09
# 3                                    1.470197e+09
# 4                                    1.795161e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.661602e+09
# 1                                   1.136567e+09
# 2                                   3.228798e+09
# 3                                   1.947907e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_year__by_geometry_building_type_recs__v14`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           512  1.291784e+05           35040
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05           35040
# 2     Multi-Family with 5+ Units          1973  4.977911e+05           35040
# 3         Single-Family Attached           715  1.803957e+05           35040
# 4         Single-Family Detached          6365  1.605900e+06           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.020682e+09
# 1                                    9.953995e+08
# 2                                    3.242654e+09
# 3                                    1.470191e+09
# 4                                    1.795160e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.661599e+09
# 1                                   1.136563e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_month__by_geometry_building_type_recs_time__v15`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count   units_count  \
# 0                 Mobile Home 2018-01-01           512  129178.43903
# 1                 Mobile Home 2018-02-01           512  129178.43903
# 2                 Mobile Home 2018-03-01           512  129178.43903
# 3                 Mobile Home 2018-04-01           512  129178.43903
# 4                 Mobile Home 2018-05-01           512  129178.43903
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.072490e+08
# 1            2688                                    9.925445e+07
# 2            2976                                    8.849594e+07
# 3            2880                                    7.825506e+07
# 4            2976                                    7.325845e+07
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   2.207729e+08
# 1                                   2.226763e+08
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v16`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           512  1.291784e+05
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05
# 2     Multi-Family with 5+ Units          1973  4.977911e+05
# 3         Single-Family Attached           715  1.803957e+05
# 4         Single-Family Detached          6365  1.605900e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.020683e+09
# 1                                    9.954026e+08
# 2                                    3.242676e+09
# 3                                    1.470197e+09
# 4                                    1.795161e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.661602e+09
# 1                                   1.136567e+09
# 2                                   3.228798e+09
# 3                                   1.947907e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_year__by_geometry_building_type_recs__v17`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           512  1.291784e+05           35040
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05           35040
# 2     Multi-Family with 5+ Units          1973  4.977911e+05           35040
# 3         Single-Family Attached           715  1.803957e+05           35040
# 4         Single-Family Detached          6365  1.605900e+06           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.020682e+09
# 1                                    9.953995e+08
# 2                                    3.242654e+09
# 3                                    1.470191e+09
# 4                                    1.795160e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.661599e+09
# 1                                   1.136563e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_month__by_geometry_building_type_recs_time__v18`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count   units_count  \
# 0                 Mobile Home 2018-01-01           512  129178.43903
# 1                 Mobile Home 2018-02-01           512  129178.43903
# 2                 Mobile Home 2018-03-01           512  129178.43903
# 3                 Mobile Home 2018-04-01           512  129178.43903
# 4                 Mobile Home 2018-05-01           512  129178.43903
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.072490e+08
# 1            2688                                    9.925445e+07
# 2            2976                                    8.849594e+07
# 3            2880                                    7.825506e+07
# 4            2976                                    7.325845e+07
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   2.207729e+08
# 1                                   2.226763e+08
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v43`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           541  1.364952e+05
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05
# 2     Multi-Family with 5+ Units          2104  5.308426e+05
# 3         Single-Family Attached           717  1.809003e+05
# 4         Single-Family Detached          6625  1.671498e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.709205e+09                          3.378014e+08
# 1                          1.138115e+09                          3.021195e+08
# 2                          3.418385e+09                          1.256120e+09
# 3                          1.953969e+09                          6.000112e+08
# 4                          3.054958e+10                          6.897142e+09

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_year__by_geometry_building_type_recs__v44`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           541  1.364952e+05           35040
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05           35040
# 2     Multi-Family with 5+ Units          2104  5.308426e+05           35040
# 3         Single-Family Attached           717  1.809003e+05           35040
# 4         Single-Family Detached          6625  1.671498e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.709202e+09                          3.378015e+08
# 1                          1.138111e+09                          3.021194e+08
# 2                          3.418365e+09                          1.256125e+09
# 3                          1.953963e+09                          6.000109e+08
# 4                          3.054956e+10                          6.897147e+09

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_month__by_geometry_building_type_recs_time__v45`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count    units_count  \
# 0                 Mobile Home 2018-01-01           541  136495.186553
# 1                 Mobile Home 2018-02-01           541  136495.186553
# 2                 Mobile Home 2018-03-01           541  136495.186553
# 3                 Mobile Home 2018-04-01           541  136495.186553
# 4                 Mobile Home 2018-05-01           541  136495.186553
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          2.248095e+08
# 1            2688                          2.264083e+08
# 2            2976                          1.431533e+08
# 3            2880                          1.161673e+08
# 4            2976                          9.066775e+07
#
#    natural_gas.total.energy_consumption
# 0                          3.256706e+07
# 1                          2.977006e+07
# 2                          3.228277e+07
# 3                          2.953698e+07
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v46`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           512  1.291784e+05
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05
# 2     Multi-Family with 5+ Units          1973  4.977911e+05
# 3         Single-Family Attached           715  1.803957e+05
# 4         Single-Family Detached          6365  1.605900e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.661602e+09                          3.329034e+08
# 1                          1.136567e+09                          3.011128e+08
# 2                          3.228798e+09                          1.132913e+09
# 3                          1.947907e+09                          6.000112e+08
# 4                          2.999420e+10                          6.852856e+09

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_year__by_geometry_building_type_recs__v47`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           512  1.291784e+05           35040
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05           35040
# 2     Multi-Family with 5+ Units          1973  4.977911e+05           35040
# 3         Single-Family Attached           715  1.803957e+05           35040
# 4         Single-Family Detached          6365  1.605900e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.661599e+09                          3.329035e+08
# 1                          1.136563e+09                          3.011126e+08
# 2                          3.228783e+09                          1.132919e+09
# 3                          1.947901e+09                          6.000109e+08
# 4                          2.999419e+10                          6.852861e+09

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_month__by_geometry_building_type_recs_time__v48`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count   units_count  \
# 0                 Mobile Home 2018-01-01           512  129178.43903
# 1                 Mobile Home 2018-02-01           512  129178.43903
# 2                 Mobile Home 2018-03-01           512  129178.43903
# 3                 Mobile Home 2018-04-01           512  129178.43903
# 4                 Mobile Home 2018-05-01           512  129178.43903
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          2.207729e+08
# 1            2688                          2.226763e+08
# 2            2976                          1.391450e+08
# 3            2880                          1.123520e+08
# 4            2976                          8.665952e+07
#
#    natural_gas.total.energy_consumption
# 0                          3.210994e+07
# 1                          2.932486e+07
# 2                          3.182789e+07
# 3                          2.911419e+07
# ...

# %% [markdown]
# ## `query__resstock_oedi__by_geometry_building_type_recs__v64`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           391  9.864994e+04
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 2     Multi-Family with 5+ Units          2001  5.048556e+05
# 3         Single-Family Attached           664  1.675283e+05
# 4         Single-Family Detached          5900  1.488580e+06
#
#    electricity.total.energy_consumption
# 0                          7.898215e+08
# 1                          8.547447e+08
# 2                          3.249347e+09
# 3                          1.345615e+09
# 4                          1.635437e+10

# %% [markdown]
# ## `query__resstock_oedi__by_state__v65`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state'],
    restrict=[('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  sample_count   units_count  electricity.total.energy_consumption
# 0    CO          9425  2.377943e+06                          2.259390e+10
# 1    WY          1105  2.787933e+05                          2.886849e+09

# %% [markdown]
# ## `query__resstock_oedi__by_geometry_building_type_recs__v70`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    avoid=[('geometry_building_type_recs', ['Mobile Home'])],
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 1     Multi-Family with 5+ Units          2001  5.048556e+05
# 2         Single-Family Attached           664  1.675283e+05
# 3         Single-Family Detached          5900  1.488580e+06
#
#    electricity.total.energy_consumption
# 0                          8.547447e+08
# 1                          3.249347e+09
# 2                          1.345615e+09
# 3                          1.635437e+10

# %% [markdown]
# ## `query__resstock_oedi__ts__by_state_time__v73`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state           timestamp  sample_count   units_count  \
# 0    CO 2018-01-01 00:15:00          9425  2.377943e+06
# 1    CO 2018-01-01 00:30:00          9425  2.377943e+06
# 2    CO 2018-01-01 00:45:00          9425  2.377943e+06
# 3    CO 2018-01-01 01:00:00          9425  2.377943e+06
# 4    CO 2018-01-01 01:15:00          9425  2.377943e+06
#
#    electricity.total.energy_consumption
# 0                          1.347721e+06
# 1                          1.360706e+06
# 2                          1.333647e+06
# 3                          1.321425e+06
# 4                          1.227585e+06

# %% [markdown]
# ## `query__resstock_oedi__ts_month__by_state_time__v74`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  timestamp  sample_count   units_count rows_per_sample  \
# 0    CO 2018-01-01          9425  2.377943e+06            2976
# 1    CO 2018-02-01          9425  2.377943e+06            2688
# 2    CO 2018-03-01          9425  2.377943e+06            2976
# 3    CO 2018-04-01          9425  2.377943e+06            2880
# 4    CO 2018-05-01          9425  2.377943e+06            2976
#
#    electricity.total.energy_consumption
# 0                          2.529477e+09
# 1                          2.335684e+09
# 2                          1.849398e+09
# 3                          1.588177e+09
# 4                          1.477754e+09

# %% [markdown]
# ## `query__resstock_oedi__ts_hour__by_state_time__v79`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='hour',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state           timestamp  sample_count   units_count rows_per_sample  \
# 0    CO 2018-01-01 00:00:00          9425  2.377943e+06               4
# 1    CO 2018-01-01 01:00:00          9425  2.377943e+06               4
# 2    CO 2018-01-01 02:00:00          9425  2.377943e+06               4
# 3    CO 2018-01-01 03:00:00          9425  2.377943e+06               4
# 4    CO 2018-01-01 04:00:00          9425  2.377943e+06               4
#
#    electricity.total.energy_consumption
# 0                          5.363499e+06
# 1                          4.908810e+06
# 2                          4.082339e+06
# 3                          4.162318e+06
# 4                          4.251390e+06

# %% [markdown]
# ## `query__resstock_oedi__ts_day__by_state_time__v82`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='day',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  timestamp  sample_count   units_count rows_per_sample  \
# 0    CO 2018-01-01          9425  2.377943e+06              96
# 1    CO 2018-01-02          9425  2.377943e+06              96
# 2    CO 2018-01-03          9425  2.377943e+06              96
# 3    CO 2018-01-04          9425  2.377943e+06              96
# 4    CO 2018-01-05          9425  2.377943e+06              96
#
#    electricity.total.energy_consumption
# 0                          1.126994e+08
# 1                          9.861118e+07
# 2                          8.659704e+07
# 3                          8.034337e+07
# 4                          7.959871e+07

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v85`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v86`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=False,
    include_savings=True,
    include_upgrade=False,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__savings
# 0                                  -4.290960e+08
# 1                                  -1.322179e+08
# 2                                  -8.874926e+06
# 3                                  -4.640286e+08
# 4                                  -1.057714e+10

# %% [markdown]
# ## `query__resstock_oedi__baseline__by_geometry_building_type_recs__v91`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          7.533442e+08                          1.275572e+09
# 1                          8.531964e+08                          1.053705e+09
# 2                          3.061449e+09                          2.344413e+09
# 3                          1.339553e+09                          1.909135e+09
# 4                          1.594169e+10                          3.121630e+10

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v92`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182440e+09                          2.384078e+08
# 1                          9.854143e+08                          2.669896e+08
# 2                          3.070324e+09                          1.090802e+09
# 3                          1.803582e+09                          5.562419e+08
# 4                          2.651883e+10                          6.236175e+09

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v93`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v100`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    7.533442e+08
# 1                                    8.531964e+08
# 2                                    3.061449e+09
# 3                                    1.339553e+09
# 4                                    1.594169e+10
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.182440e+09
# 1                                   9.854143e+08
# 2                                   3.070324e+09
# 3                                   1.803582e+09
# ...

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v103`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count    units_count  \
# 0                    Mobile Home           142   35826.832700
# 1  Multi-Family with 2 - 4 Units            74   18670.321266
# 2     Multi-Family with 5+ Units           101   25482.465512
# 3         Single-Family Attached            53   13371.986853
# 4         Single-Family Detached           665  167780.589756
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    2.673389e+08
# 1                                    1.422061e+08
# 2                                    1.812277e+08
# 3                                    1.306436e+08
# 4                                    2.009919e+09
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   4.791617e+08
# 1                                   1.511522e+08
# 2                                   1.584742e+08
# 3                                   1.443247e+08
# ...

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v112`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0     1415
# 1     2279
# 2     4588
# 3     4893
# 4     5512

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v113`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0       33
# 1     5512
# 2     5957
# 3     8957
# 4    11111

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v114`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0      686
# 1     1764
# 2     7573
# 3     8355
# 4    10387

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v115`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182440e+09                          2.384078e+08
# 1                          9.854143e+08                          2.669896e+08
# 2                          3.070324e+09                          1.090802e+09
# 3                          1.803582e+09                          5.562419e+08
# 4                          2.651883e+10                          6.236175e+09

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v116`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0     1692
# 1     1964
# 2     4142
# 3     7258
# 4     9998

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v117`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0     2724
# 1     7892
# 2     7918
# 3     9236
# 4    14671

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v118`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0      244
# 1      565
# 2     1407
# 3     3120
# 4     5820

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v119`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           512  1.291784e+05
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05
# 2     Multi-Family with 5+ Units          1973  4.977911e+05
# 3         Single-Family Attached           715  1.803957e+05
# 4         Single-Family Detached          6365  1.605900e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.661602e+09                          3.329034e+08
# 1                          1.136567e+09                          3.011128e+08
# 2                          3.228798e+09                          1.132913e+09
# 3                          1.947907e+09                          6.000112e+08
# 4                          2.999420e+10                          6.852856e+09

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v120`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['WY'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0    25369
# 1    33861
# 2    79359
# 3    88289
# 4    91566

# %% [markdown]
# ## `get_building_ids__resstock_oedi__v139`
#
# Auto-recorded from test_invariants (get_building_ids, resstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id
# 0       13
# 1       16
# 2       33
# 3      128
# 4      182

# %% [markdown]
# ## `query__resstock_oedi__by_geometry_building_type_recs__v142`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.natural_gas.total.energy_consumption'],
    get_nonzero_count=True,
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           391  9.864994e+04
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 2     Multi-Family with 5+ Units          2001  5.048556e+05
# 3         Single-Family Attached           664  1.675283e+05
# 4         Single-Family Detached          5900  1.488580e+06
#
#    natural_gas.total.energy_consumption  \
# 0                          1.279629e+09
# 1                          1.054712e+09
# 2                          2.466138e+09
# 3                          1.909135e+09
# 4                          3.124770e+10
#
#    natural_gas.total.energy_consumption__nonzero_units_count
# 0                                       7.266287e+04
# 1                                       9.259470e+04
# 2                                       3.476717e+05
# 3                                       1.382613e+05
# 4                                       1.211300e+06

# %% [markdown]
# ## `query__resstock_oedi__by_vintage__v145`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['vintage'],
    limit=5,
    restrict=[('state', ['CO'])],
    sort=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   vintage  sample_count    units_count  electricity.total.energy_consumption
# 0   1940s           240   60552.393295                          5.792687e+08
# 1   1950s           702  177115.750389                          1.651332e+09
# 2   1960s           805  203102.819178                          1.999671e+09
# 3   1970s          1755  442789.375972                          4.193620e+09
# 4   1980s          1362  343634.831951                          3.374342e+09

# %% [markdown]
# ## `query__resstock_oedi__by_geometry_building_type_recs__v148`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    agg_func='mean',
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           391  9.864994e+04
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 2     Multi-Family with 5+ Units          2001  5.048556e+05
# 3         Single-Family Attached           664  1.675283e+05
# 4         Single-Family Detached          5900  1.488580e+06
#
#    electricity.total.energy_consumption__mean
# 0                                 8006.304380
# 1                                 7223.430772
# 2                                 6436.190746
# 3                                 8032.167041
# 4                                10986.559115

# %% [markdown]
# ## `query__resstock_oedi__u1__by_geometry_building_type_recs__v161`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='baseline')],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  elec_minus_gas
# 0                    Mobile Home           541  1.364952e+05    1.371404e+09
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05    8.359953e+08
# 2     Multi-Family with 5+ Units          2104  5.308426e+05    2.162265e+09
# 3         Single-Family Attached           717  1.809003e+05    1.353957e+09
# 4         Single-Family Detached          6625  1.671498e+06    2.365244e+10

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_year__by_geometry_building_type_recs__v162`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           541  1.364952e+05           35040
# 1  Multi-Family with 2 - 4 Units           543  1.369998e+05           35040
# 2     Multi-Family with 5+ Units          2104  5.308426e+05           35040
# 3         Single-Family Attached           717  1.809003e+05           35040
# 4         Single-Family Detached          6625  1.671498e+06           35040
#
#    elec_minus_gas
# 0    1.371401e+09
# 1    8.359917e+08
# 2    2.162240e+09
# 3    1.353952e+09
# 4    2.365242e+10

# %% [markdown]
# ## `query__resstock_oedi__u1__ts_month__by_geometry_building_type_recs_time__v163`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count    units_count  \
# 0                 Mobile Home 2018-01-01           541  136495.186553
# 1                 Mobile Home 2018-02-01           541  136495.186553
# 2                 Mobile Home 2018-03-01           541  136495.186553
# 3                 Mobile Home 2018-04-01           541  136495.186553
# 4                 Mobile Home 2018-05-01           541  136495.186553
#
#   rows_per_sample  elec_minus_gas
# 0            2976    1.922425e+08
# 1            2688    1.966383e+08
# 2            2976    1.108706e+08
# 3            2880    8.663030e+07
# 4            2976    6.241099e+07

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__by_geometry_building_type_recs__v164`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='baseline')],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  elec_minus_gas
# 0                    Mobile Home           512  1.291784e+05    1.328699e+09
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05    8.354538e+08
# 2     Multi-Family with 5+ Units          1973  4.977911e+05    2.095885e+09
# 3         Single-Family Attached           715  1.803957e+05    1.347896e+09
# 4         Single-Family Detached          6365  1.605900e+06    2.314134e+10

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_year__by_geometry_building_type_recs__v165`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           512  1.291784e+05           35040
# 1  Multi-Family with 2 - 4 Units           541  1.364952e+05           35040
# 2     Multi-Family with 5+ Units          1973  4.977911e+05           35040
# 3         Single-Family Attached           715  1.803957e+05           35040
# 4         Single-Family Detached          6365  1.605900e+06           35040
#
#    elec_minus_gas
# 0    1.328696e+09
# 1    8.354499e+08
# 2    2.095864e+09
# 3    1.347890e+09
# 4    2.314133e+10

# %% [markdown]
# ## `query__resstock_oedi__applied__u1__ts_month__by_geometry_building_type_recs_time__v166`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO', 'WY'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count   units_count  \
# 0                 Mobile Home 2018-01-01           512  129178.43903
# 1                 Mobile Home 2018-02-01           512  129178.43903
# 2                 Mobile Home 2018-03-01           512  129178.43903
# 3                 Mobile Home 2018-04-01           512  129178.43903
# 4                 Mobile Home 2018-05-01           512  129178.43903
#
#   rows_per_sample  elec_minus_gas
# 0            2976    1.886629e+08
# 1            2688    1.933515e+08
# 2            2976    1.073171e+08
# 3            2880    8.323784e+07
# 4            2976    5.881508e+07

# %% [markdown]
# ## `query__resstock_oedi__v179`
#
# Auto-recorded from test_invariants (query, resstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption'],
    group_by=[MappedColumn(bsq=bsq, name='simple_bldg_type', mapping_dict={'Mobile Home': 'MH', 'Multi-Family with 2 - 4 Units': 'MF', 'Multi-Family with 5+ Units': 'MF', 'Single-Family Attached': 'SF', 'Single-Family Detached': 'SF'}, key=bsq._get_column('geometry_building_type_recs'))],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   simple_bldg_type  sample_count   units_count  \
# 0               MF          2470  6.231850e+05
# 1               MH           391  9.864994e+04
# 2               SF          6564  1.656108e+06
#
#    electricity.total.energy_consumption
# 0                          4.104092e+09
# 1                          7.898215e+08
# 2                          1.769998e+10
