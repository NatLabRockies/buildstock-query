# %% [markdown]
# # Example queries: `invariants_three_way` (resstock_oedi)
#
# Auto-generated from `tests/query_snapshots/invariants_three_way.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/resstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/resstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "resstock_2024_amy2018_release_2",
    buildstock_type="resstock",
    db_schema="resstock_oedi_vu",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading resstock_2024_amy2018_release_2 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso

# %% [markdown]
# ## `inv_baseline_ts_year_by_building_type`
#
# Three-way invariant: ts-year-collapse leg, baseline. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='0',
    annual_only=False,
    timestamp_grouping_func='year',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           391  9.864994e+04           35040
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05           35040
# 2     Multi-Family with 5+ Units          2001  5.048556e+05           35040
# 3         Single-Family Attached           664  1.675283e+05           35040
# 4         Single-Family Detached          5900  1.488580e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          7.898218e+08                          1.279629e+09
# 1                          8.547433e+08                          1.054711e+09
# 2                          3.249322e+09                          2.466140e+09
# 3                          1.345610e+09                          1.909135e+09
# 4                          1.635436e+10                          3.124769e+10

# %% [markdown]
# ## `inv_upgrade1_annual_by_building_type`
#
# Three-way invariant: annual leg, upgrade 1 (no applied filter), CO. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=False,
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           391  9.864994e+04
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05
# 2     Multi-Family with 5+ Units          2001  5.048556e+05
# 3         Single-Family Attached           664  1.675283e+05
# 4         Single-Family Detached          5900  1.488580e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.218917e+09                          2.424648e+08
# 1                          9.869626e+08                          2.679964e+08
# 2                          3.258222e+09                          1.212528e+09
# 3                          1.809644e+09                          5.562419e+08
# 4                          2.693151e+10                          6.267570e+09

# %% [markdown]
# ## `inv_upgrade1_ts_year_by_building_type`
#
# Three-way invariant: ts-year-collapse leg, upgrade 1 (no applied filter). Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=False,
    annual_only=False,
    timestamp_grouping_func='year',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           391  9.864994e+04           35040
# 1  Multi-Family with 2 - 4 Units           469  1.183295e+05           35040
# 2     Multi-Family with 5+ Units          2001  5.048556e+05           35040
# 3         Single-Family Attached           664  1.675283e+05           35040
# 4         Single-Family Detached          5900  1.488580e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.218916e+09                          2.424648e+08
# 1                          9.869596e+08                          2.679962e+08
# 2                          3.258204e+09                          1.212533e+09
# 3                          1.809639e+09                          5.562417e+08
# 4                          2.693150e+10                          6.267574e+09

# %% [markdown]
# ## `inv_upgrade1_ts_monthly_by_building_type`
#
# Three-way invariant: ts-monthly leg, upgrade 1 (no applied filter). Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=False,
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count   units_count  \
# 0                 Mobile Home 2018-01-01           391  98649.940744
# 1                 Mobile Home 2018-02-01           391  98649.940744
# 2                 Mobile Home 2018-03-01           391  98649.940744
# 3                 Mobile Home 2018-04-01           391  98649.940744
# 4                 Mobile Home 2018-05-01           391  98649.940744
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.592182e+08
# 1            2688                          1.507334e+08
# 2            2976                          9.978676e+07
# 3            2880                          8.230597e+07
# 4            2976                          6.694454e+07
#
#    natural_gas.total.energy_consumption
# 0                          2.342444e+07
# 1                          2.144512e+07
# 2                          2.313398e+07
# 3                          2.115430e+07
# 4                          2.022271e+07

# %% [markdown]
# ## `inv_upgrade1_applied_annual_by_building_type`
#
# Three-way invariant: annual leg, upgrade 1, applied_only=True. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182440e+09                          2.384078e+08
# 1                          9.854143e+08                          2.669896e+08
# 2                          3.070324e+09                          1.090802e+09
# 3                          1.803582e+09                          5.562419e+08
# 4                          2.651883e+10                          6.236175e+09

# %% [markdown]
# ## `inv_upgrade1_applied_ts_year_by_building_type`
#
# Three-way invariant: ts-year-collapse leg, upgrade 1, applied_only=True. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    annual_only=False,
    timestamp_grouping_func='year',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           370  9.335161e+04           35040
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05           35040
# 2     Multi-Family with 5+ Units          1872  4.723087e+05           35040
# 3         Single-Family Attached           662  1.670237e+05           35040
# 4         Single-Family Detached          5700  1.438119e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182439e+09                          2.384077e+08
# 1                          9.854111e+08                          2.669895e+08
# 2                          3.070310e+09                          1.090808e+09
# 3                          1.803577e+09                          5.562417e+08
# 4                          2.651882e+10                          6.236179e+09

# %% [markdown]
# ## `inv_upgrade1_applied_ts_monthly_by_building_type`
#
# Three-way invariant: ts-monthly leg, upgrade 1, applied_only=True. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count  units_count  \
# 0                 Mobile Home 2018-01-01           370  93351.60633
# 1                 Mobile Home 2018-02-01           370  93351.60633
# 2                 Mobile Home 2018-03-01           370  93351.60633
# 3                 Mobile Home 2018-04-01           370  93351.60633
# 4                 Mobile Home 2018-05-01           370  93351.60633
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.561855e+08
# 1            2688                          1.479049e+08
# 2            2976                          9.676503e+07
# 3            2880                          7.940906e+07
# 4            2976                          6.385217e+07
#
#    natural_gas.total.energy_consumption
# 0                          2.304681e+07
# 1                          2.107219e+07
# 2                          2.275800e+07
# 3                          2.080502e+07
# 4                          1.987977e+07

# %% [markdown]
# ## `inv_upgrade1_applied_in_1_2_annual_by_building_type`
#
# Three-way invariant: annual leg, upgrade 1, applied_only=True, applied_in=[1,2]. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    applied_in=[1, 2],
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count  \
# 0                    Mobile Home           370  9.335161e+04
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05
# 2     Multi-Family with 5+ Units          1872  4.723087e+05
# 3         Single-Family Attached           662  1.670237e+05
# 4         Single-Family Detached          5700  1.438119e+06
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182440e+09                          2.384078e+08
# 1                          9.854143e+08                          2.669896e+08
# 2                          3.070324e+09                          1.090802e+09
# 3                          1.803582e+09                          5.562419e+08
# 4                          2.651883e+10                          6.236175e+09

# %% [markdown]
# ## `inv_upgrade1_applied_in_1_2_ts_year_by_building_type`
#
# Three-way invariant: ts-year-collapse leg, upgrade 1, applied_only=True, applied_in=[1,2]. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    applied_in=[1, 2],
    annual_only=False,
    timestamp_grouping_func='year',
    group_by=['geometry_building_type_recs'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#      geometry_building_type_recs  sample_count   units_count rows_per_sample  \
# 0                    Mobile Home           370  9.335161e+04           35040
# 1  Multi-Family with 2 - 4 Units           467  1.178249e+05           35040
# 2     Multi-Family with 5+ Units          1872  4.723087e+05           35040
# 3         Single-Family Attached           662  1.670237e+05           35040
# 4         Single-Family Detached          5700  1.438119e+06           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.182439e+09                          2.384077e+08
# 1                          9.854111e+08                          2.669895e+08
# 2                          3.070310e+09                          1.090808e+09
# 3                          1.803577e+09                          5.562417e+08
# 4                          2.651882e+10                          6.236179e+09

# %% [markdown]
# ## `inv_upgrade1_applied_in_1_2_ts_monthly_by_building_type`
#
# Three-way invariant: ts-monthly leg, upgrade 1, applied_only=True, applied_in=[1,2]. Two fuels.

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    upgrade_id='1',
    applied_only=True,
    applied_in=[1, 2],
    annual_only=False,
    timestamp_grouping_func='month',
    group_by=['geometry_building_type_recs', 'time'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   geometry_building_type_recs  timestamp  sample_count  units_count  \
# 0                 Mobile Home 2018-01-01           370  93351.60633
# 1                 Mobile Home 2018-02-01           370  93351.60633
# 2                 Mobile Home 2018-03-01           370  93351.60633
# 3                 Mobile Home 2018-04-01           370  93351.60633
# 4                 Mobile Home 2018-05-01           370  93351.60633
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.561855e+08
# 1            2688                          1.479049e+08
# 2            2976                          9.676503e+07
# 3            2880                          7.940906e+07
# 4            2976                          6.385217e+07
#
#    natural_gas.total.energy_consumption
# 0                          2.304681e+07
# 1                          2.107219e+07
# 2                          2.275800e+07
# 3                          2.080502e+07
# 4                          1.987977e+07
