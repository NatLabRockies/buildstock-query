# %% [markdown]
# # Example queries: `from_invariants` (comstock_oedi)
#
# Auto-generated from `tests/query_snapshots/from_invariants.json`. Each cell
# runs one entry from the snapshot suite. Regenerate by running the
# matching test with `--update-snapshot` or `--overwrite-snapshot`.

# %%
from pathlib import Path
from buildstock_query import BuildStockQuery
from buildstock_query.schema.utilities import MappedColumn
import pandas as pd

# %% [markdown]
# ## Construct the BuildStockQuery object
#
# `cache_folder` points at the snapshot test cache directory so this
# notebook reuses parquets that the test suite has already downloaded
# from Athena. Queries that are already cached return immediately;
# anything new still hits Athena.

# %%
# This notebook lives in `tests/example_notebooks/`; the snapshot test
# cache is its sibling `tests/query_snapshots/comstock_oedi_cache/`. Resolve
# the path relative to the notebook directory (`_dh[0]` is set by
# IPython at kernel startup; falls back to CWD outside Jupyter).
_NB_DIR = Path(_dh[0] if "_dh" in globals() else ".").resolve()
_CACHE = (_NB_DIR / "../query_snapshots/comstock_oedi_cache").resolve()
bsq = BuildStockQuery(
    "rescore",
    "buildstock_sdr",
    "comstock_amy2018_r2_2025",
    buildstock_type="comstock",
    db_schema="comstock_oedi_state_and_county",
    skip_reports=True,
    cache_folder=str(_CACHE),
)
# Out:
# INFO:buildstock_query.query_core:Loading comstock_amy2018_r2_2025 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso
# INFO:botocore.tokens:SSO Token refresh succeeded

# %% [markdown]
# ## `query__comstock_oedi__v3`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count  electricity.total.energy_consumption..kwh  \
# 0        134649  84415.71204                               1.600424e+10
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.829994e+09

# %% [markdown]
# ## `query__comstock_oedi__by_comstock_building_type__v4`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         13461  4556.431396
# 1               Hospital            73   152.003100
# 2             LargeHotel          2815  3317.336942
# 3            LargeOffice          2271   849.927533
# 4           MediumOffice          8708  2418.404703
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08

# %% [markdown]
# ## `query__comstock_oedi__baseline__by_comstock_building_type__v19`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         17761  6481.401989
# 1               Hospital           175   384.224912
# 2             LargeHotel          3562  3836.361595
# 3            LargeOffice          2444   920.591301
# 4           MediumOffice         10251  2903.093740
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.624013e+09
# 1                               2.033883e+09
# 2                               1.368301e+09
# 3                               1.641582e+09
# 4                               1.536703e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.564653e+09
# 1                               1.233206e+09
# 2                               1.092790e+09
# 3                               4.703962e+08
# 4                               4.469503e+08

# %% [markdown]
# ## `query__comstock_oedi__baseline__ts_year__by_comstock_building_type__v20`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         17761  6481.401989           35040
# 1               Hospital           175   384.224912           35040
# 2             LargeHotel          3562  3836.361595           35040
# 3            LargeOffice          2444   920.591301           35040
# 4           MediumOffice         10251  2903.093740           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.624013e+09                          1.565700e+09
# 1                          2.033883e+09                          1.234031e+09
# 2                          1.368301e+09                          1.093520e+09
# 3                          1.641582e+09                          4.707112e+08
# 4                          1.536703e+09                          4.472496e+08

# %% [markdown]
# ## `query__comstock_oedi__baseline__ts_month__by_comstock_building_type_time__v21`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         17761  6481.401989
# 1  FullServiceRestaurant 2018-02-01         17761  6481.401989
# 2  FullServiceRestaurant 2018-03-01         17761  6481.401989
# 3  FullServiceRestaurant 2018-04-01         17761  6481.401989
# 4  FullServiceRestaurant 2018-05-01         17761  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.364880e+08
# 1            2688                          1.256194e+08
# 2            2976                          1.284009e+08
# 3            2880                          1.239559e+08
# 4            2976                          1.355445e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.679840e+08
# 1                          1.533654e+08
# 2                          1.389757e+08
# 3                          1.242156e+08
# 4                          1.118380e+08

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v22`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         17761  6481.401989
# 1               Hospital           175   384.224912
# 2             LargeHotel          3562  3836.361595
# 3            LargeOffice          2444   920.591301
# 4           MediumOffice         10251  2903.093740
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.624013e+09
# 1                                       2.033883e+09
# 2                                       1.368301e+09
# 3                                       1.641582e+09
# 4                                       1.536703e+09
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.591728e+09
# 1                                       2.032565e+09
# 2                                       1.368301e+09
# 3                                       1.640506e+09
# 4                                       1.505989e+09
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       3.228523e+07
# 1                                       1.317935e+06
# 2                                       0.000000e+00
# 3                                       1.075637e+06
# 4                                       3.071321e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.564653e+09
# 1                                       1.233206e+09
# 2                                       1.092790e+09
# 3                                       4.703962e+08
# 4                                       4.469503e+08
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       1.324389e+09
# 1                                       1.232085e+09
# 2                                       1.092790e+09
# 3                                       4.686625e+08
# 4                                       3.955813e+08
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.402642e+08
# 1                                       1.120960e+06
# 2                                       0.000000e+00
# 3                                       1.733681e+06
# 4                                       5.136897e+07

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_year__by_comstock_building_type__v23`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         17761  6481.401989           35040
# 1               Hospital           175   384.224912           35040
# 2             LargeHotel          3562  3836.361595           35040
# 3            LargeOffice          2444   920.591301           35040
# 4           MediumOffice         10251  2903.093740           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.624013e+09
# 1                                    2.033883e+09
# 2                                    1.368301e+09
# 3                                    1.641582e+09
# 4                                    1.536703e+09
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.591728e+09
# 1                                   2.032565e+09
# 2                                   1.368301e+09
# 3                                   1.640506e+09
# 4                                   1.505990e+09
#
#    electricity.total.energy_consumption__savings  \
# 0                                   3.228499e+07
# 1                                   1.317934e+06
# 2                                   0.000000e+00
# 3                                   1.075638e+06
# 4                                   3.071321e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.565700e+09
# 1                                    1.234031e+09
# 2                                    1.093520e+09
# 3                                    4.707112e+08
# 4                                    4.472496e+08
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.325275e+09
# 1                                   1.232910e+09
# 2                                   1.093520e+09
# 3                                   4.689763e+08
# 4                                   3.958463e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   2.404253e+08
# 1                                   1.121703e+06
# 2                                   0.000000e+00
# 3                                   1.734845e+06
# 4                                   5.140332e+07

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_month__by_comstock_building_type_time__v24`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         17761  6481.401989
# 1  FullServiceRestaurant 2018-02-01         17761  6481.401989
# 2  FullServiceRestaurant 2018-03-01         17761  6481.401989
# 3  FullServiceRestaurant 2018-04-01         17761  6481.401989
# 4  FullServiceRestaurant 2018-05-01         17761  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.364880e+08
# 1            2688                                    1.256194e+08
# 2            2976                                    1.284009e+08
# 3            2880                                    1.239559e+08
# 4            2976                                    1.355445e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.502726e+08
# 1                                   1.421485e+08
# 2                                   1.255408e+08
# 3                                   1.181610e+08
# 4                                   1.243772e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -1.378465e+07
# 1                                  -1.652909e+07
# 2                                   2.860143e+06
# 3                                   5.794914e+06
# 4                                   1.116727e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.679840e+08
# 1                                    1.533654e+08
# 2                                    1.389757e+08
# 3                                    1.242156e+08
# 4                                    1.118380e+08
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.204465e+08
# 1                                   1.096406e+08
# 2                                   1.149062e+08
# 3                                   1.087103e+08
# 4                                   1.084215e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   4.753750e+07
# 1                                   4.372476e+07
# 2                                   2.406951e+07
# 3                                   1.550531e+07
# 4                                   3.416485e+06

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v25`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         15988  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            27    17.120897
# 3           MediumOffice          2170   733.337073
# 4             Outpatient          1095  1789.764634
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.457327e+09
# 1                                       7.905386e+06
# 2                                       8.724252e+06
# 3                                       2.375055e+08
# 4                                       2.302601e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.425042e+09
# 1                                       6.587452e+06
# 2                                       7.648615e+06
# 3                                       2.067922e+08
# 4                                       2.060655e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       3.228523e+07
# 1                                       1.317935e+06
# 2                                       1.075637e+06
# 3                                       3.071321e+07
# 4                                       2.419465e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.460704e+09
# 1                                       2.425941e+06
# 2                                       1.788549e+06
# 3                                       5.577121e+07
# 4                                       8.188433e+07
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       1.220440e+09
# 1                                       1.304981e+06
# 2                                       5.486811e+04
# 3                                       4.402240e+06
# 4                                       1.987862e+07
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.402642e+08
# 1                                       1.120960e+06
# 2                                       1.733681e+06
# 3                                       5.136897e+07
# 4                                       6.200572e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_comstock_building_type__v26`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         15988  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            27    17.120897           35040
# 3           MediumOffice          2170   733.337073           35040
# 4             Outpatient          1095  1789.764634           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.457326e+09
# 1                                    7.905383e+06
# 2                                    8.724251e+06
# 3                                    2.375054e+08
# 4                                    2.302599e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.425041e+09
# 1                                   6.587449e+06
# 2                                   7.648613e+06
# 3                                   2.067922e+08
# 4                                   2.060657e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                   3.228499e+07
# 1                                   1.317934e+06
# 2                                   1.075638e+06
# 3                                   3.071321e+07
# 4                                   2.419427e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.461682e+09
# 1                                    2.427562e+06
# 2                                    1.789755e+06
# 3                                    5.580865e+07
# 4                                    8.193878e+07
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.221256e+09
# 1                                   1.305859e+06
# 2                                   5.491002e+04
# 3                                   4.405337e+06
# 4                                   1.989197e+07
#
#    natural_gas.total.energy_consumption__savings
# 0                                   2.404253e+08
# 1                                   1.121703e+06
# 2                                   1.734845e+06
# 3                                   5.140332e+07
# 4                                   6.204681e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_comstock_building_type_time__v27`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         15988  6046.539978
# 1  FullServiceRestaurant 2018-02-01         15988  6046.539978
# 2  FullServiceRestaurant 2018-03-01         15988  6046.539978
# 3  FullServiceRestaurant 2018-04-01         15988  6046.539978
# 4  FullServiceRestaurant 2018-05-01         15988  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.209618e+08
# 1            2688                                    1.112006e+08
# 2            2976                                    1.150298e+08
# 3            2880                                    1.113886e+08
# 4            2976                                    1.224167e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.347465e+08
# 1                                   1.277297e+08
# 2                                   1.121696e+08
# 3                                   1.055937e+08
# 4                                   1.112494e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -1.378465e+07
# 1                                  -1.652909e+07
# 2                                   2.860143e+06
# 3                                   5.794914e+06
# 4                                   1.116727e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.574850e+08
# 1                                    1.435009e+08
# 2                                    1.297085e+08
# 3                                    1.158058e+08
# 4                                    1.040537e+08
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.099475e+08
# 1                                   9.977619e+07
# 2                                   1.056390e+08
# 3                                   1.003005e+08
# 4                                   1.006373e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   4.753750e+07
# 1                                   4.372476e+07
# 2                                   2.406951e+07
# 3                                   1.550531e+07
# 4                                   3.416485e+06

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v28`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         15988  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            27    17.120897
# 3           MediumOffice          2170   733.337073
# 4             Outpatient          1081  1780.638615
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.457327e+09
# 1                                       7.905386e+06
# 2                                       8.724252e+06
# 3                                       2.375055e+08
# 4                                       2.239151e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.425042e+09
# 1                                       6.587452e+06
# 2                                       7.648615e+06
# 3                                       2.067922e+08
# 4                                       2.003235e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       3.228523e+07
# 1                                       1.317935e+06
# 2                                       1.075637e+06
# 3                                       3.071321e+07
# 4                                       2.359164e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.460704e+09
# 1                                       2.425941e+06
# 2                                       1.788549e+06
# 3                                       5.577121e+07
# 4                                       7.928152e+07
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       1.220440e+09
# 1                                       1.304981e+06
# 2                                       5.486811e+04
# 3                                       4.402240e+06
# 4                                       1.944832e+07
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.402642e+08
# 1                                       1.120960e+06
# 2                                       1.733681e+06
# 3                                       5.136897e+07
# 4                                       5.983319e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_comstock_building_type__v29`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         15988  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            27    17.120897           35040
# 3           MediumOffice          2170   733.337073           35040
# 4             Outpatient          1081  1780.638615           35040
#
#    electricity.total.energy_consumption__baseline  \
# 0                                    1.457326e+09
# 1                                    7.905383e+06
# 2                                    8.724251e+06
# 3                                    2.375054e+08
# 4                                    2.239149e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.425041e+09
# 1                                   6.587449e+06
# 2                                   7.648613e+06
# 3                                   2.067922e+08
# 4                                   2.003237e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                   3.228499e+07
# 1                                   1.317934e+06
# 2                                   1.075638e+06
# 3                                   3.071321e+07
# 4                                   2.359128e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.461682e+09
# 1                                    2.427562e+06
# 2                                    1.789755e+06
# 3                                    5.580865e+07
# 4                                    7.933422e+07
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.221256e+09
# 1                                   1.305859e+06
# 2                                   5.491002e+04
# 3                                   4.405337e+06
# 4                                   1.946139e+07
#
#    natural_gas.total.energy_consumption__savings
# 0                                   2.404253e+08
# 1                                   1.121703e+06
# 2                                   1.734845e+06
# 3                                   5.140332e+07
# 4                                   5.987282e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_comstock_building_type_time__v30`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         15988  6046.539978
# 1  FullServiceRestaurant 2018-02-01         15988  6046.539978
# 2  FullServiceRestaurant 2018-03-01         15988  6046.539978
# 3  FullServiceRestaurant 2018-04-01         15988  6046.539978
# 4  FullServiceRestaurant 2018-05-01         15988  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption__baseline  \
# 0            2976                                    1.209618e+08
# 1            2688                                    1.112006e+08
# 2            2976                                    1.150298e+08
# 3            2880                                    1.113886e+08
# 4            2976                                    1.224167e+08
#
#    electricity.total.energy_consumption__upgrade  \
# 0                                   1.347465e+08
# 1                                   1.277297e+08
# 2                                   1.121696e+08
# 3                                   1.055937e+08
# 4                                   1.112494e+08
#
#    electricity.total.energy_consumption__savings  \
# 0                                  -1.378465e+07
# 1                                  -1.652909e+07
# 2                                   2.860143e+06
# 3                                   5.794914e+06
# 4                                   1.116727e+07
#
#    natural_gas.total.energy_consumption__baseline  \
# 0                                    1.574850e+08
# 1                                    1.435009e+08
# 2                                    1.297085e+08
# 3                                    1.158058e+08
# 4                                    1.040537e+08
#
#    natural_gas.total.energy_consumption__upgrade  \
# 0                                   1.099475e+08
# 1                                   9.977619e+07
# 2                                   1.056390e+08
# 3                                   1.003005e+08
# 4                                   1.006373e+08
#
#    natural_gas.total.energy_consumption__savings
# 0                                   4.753750e+07
# 1                                   4.372476e+07
# 2                                   2.406951e+07
# 3                                   1.550531e+07
# 4                                   3.416485e+06

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v49`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         17761  6481.401989
# 1               Hospital           175   384.224912
# 2             LargeHotel          3562  3836.361595
# 3            LargeOffice          2444   920.591301
# 4           MediumOffice         10251  2903.093740
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.591728e+09
# 1                               2.032565e+09
# 2                               1.368301e+09
# 3                               1.640506e+09
# 4                               1.505989e+09
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.324389e+09
# 1                               1.232085e+09
# 2                               1.092790e+09
# 3                               4.686625e+08
# 4                               3.955813e+08

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_year__by_comstock_building_type__v50`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         17761  6481.401989           35040
# 1               Hospital           175   384.224912           35040
# 2             LargeHotel          3562  3836.361595           35040
# 3            LargeOffice          2444   920.591301           35040
# 4           MediumOffice         10251  2903.093740           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.591728e+09                          1.325275e+09
# 1                          2.032565e+09                          1.232910e+09
# 2                          1.368301e+09                          1.093520e+09
# 3                          1.640506e+09                          4.689763e+08
# 4                          1.505990e+09                          3.958463e+08

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_month__by_comstock_building_type_time__v51`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         17761  6481.401989
# 1  FullServiceRestaurant 2018-02-01         17761  6481.401989
# 2  FullServiceRestaurant 2018-03-01         17761  6481.401989
# 3  FullServiceRestaurant 2018-04-01         17761  6481.401989
# 4  FullServiceRestaurant 2018-05-01         17761  6481.401989
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.502726e+08
# 1            2688                          1.421485e+08
# 2            2976                          1.255408e+08
# 3            2880                          1.181610e+08
# 4            2976                          1.243772e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.204465e+08
# 1                          1.096406e+08
# 2                          1.149062e+08
# 3                          1.087103e+08
# 4                          1.084215e+08

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v52`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         15988  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            27    17.120897
# 3           MediumOffice          2170   733.337073
# 4             Outpatient          1095  1789.764634
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.425042e+09
# 1                               6.587452e+06
# 2                               7.648615e+06
# 3                               2.067922e+08
# 4                               2.060655e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.220440e+09
# 1                               1.304981e+06
# 2                               5.486811e+04
# 3                               4.402240e+06
# 4                               1.987862e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_comstock_building_type__v53`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         15988  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            27    17.120897           35040
# 3           MediumOffice          2170   733.337073           35040
# 4             Outpatient          1095  1789.764634           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.425041e+09                          1.221256e+09
# 1                          6.587449e+06                          1.305859e+06
# 2                          7.648613e+06                          5.491002e+04
# 3                          2.067922e+08                          4.405337e+06
# 4                          2.060657e+08                          1.989197e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_comstock_building_type_time__v54`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         15988  6046.539978
# 1  FullServiceRestaurant 2018-02-01         15988  6046.539978
# 2  FullServiceRestaurant 2018-03-01         15988  6046.539978
# 3  FullServiceRestaurant 2018-04-01         15988  6046.539978
# 4  FullServiceRestaurant 2018-05-01         15988  6046.539978
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.347465e+08
# 1            2688                          1.277297e+08
# 2            2976                          1.121696e+08
# 3            2880                          1.055937e+08
# 4            2976                          1.112494e+08
#
#    natural_gas.total.energy_consumption
# 0                          1.099475e+08
# 1                          9.977619e+07
# 2                          1.056390e+08
# 3                          1.003005e+08
# 4                          1.006373e+08

# %% [markdown]
# ## `query__comstock_oedi__ts_year__v61`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count rows_per_sample  \
# 0        134649  84415.71204           35040
#
#    electricity.total.energy_consumption
# 0                          1.600424e+10

# %% [markdown]
# ## `query__comstock_oedi__ts_year__by_in.county_name__v62`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['in.county_name'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#             county_name  sample_count  units_count rows_per_sample  \
# 0      CO, Adams County         10170  8130.650795           35040
# 1    CO, Alamosa County           447   231.643122           35040
# 2   CO, Arapahoe County         13494  8111.235765           35040
# 3  CO, Archuleta County           324   152.825688           35040
# 4       CO, Baca County            78    32.398055           35040
#
#    electricity.total.energy_consumption
# 0                          1.542441e+09
# 1                          2.512239e+07
# 2                          1.740775e+09
# 3                          1.323592e+07
# 4                          4.982582e+06

# %% [markdown]
# ## `query__comstock_oedi__ts_year__by_in.nhgis_tract_gisjoin__v63`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['in.nhgis_tract_gisjoin'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
#   nhgis_tract_gisjoin  sample_count  units_count rows_per_sample  \
# 0      G0800010007801           148   109.689608           35040
# 1      G0800010007802           115    42.020192           35040
# 2      G0800010007900           104    34.658314           35040
# 3      G0800010008000            46    14.126677           35040
# 4      G0800010008100            37    32.023338           35040
#
#    electricity.total.energy_consumption
# 0                          8.881154e+06
# 1                          8.831946e+06
# 2                          6.320033e+06
# 3                          4.262248e+06
# 4                          1.274415e+07

# %% [markdown]
# ## `query__comstock_oedi__by_comstock_building_type__v66`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         13461  4556.431396
# 1               Hospital            73   152.003100
# 2             LargeHotel          2815  3317.336942
# 3            LargeOffice          2271   849.927533
# 4           MediumOffice          8708  2418.404703
#
#    electricity.total.energy_consumption..kwh
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09

# %% [markdown]
# ## `query__comstock_oedi__by_state__v67`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state'],
    restrict=[('state', ['CO', 'WY'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  sample_count   units_count  electricity.total.energy_consumption..kwh
# 0    CO        134649  84415.712040                               1.600424e+10
# 1    WY         18630  11666.235991                               1.768901e+09

# %% [markdown]
# ## `query__comstock_oedi__by_comstock_building_type__v71`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    avoid=[('comstock_building_type', ['Warehouse'])],
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         13461  4556.431396
# 1               Hospital            73   152.003100
# 2             LargeHotel          2815  3317.336942
# 3            LargeOffice          2271   849.927533
# 4           MediumOffice          8708  2418.404703
#
#    electricity.total.energy_consumption..kwh
# 0                               1.209202e+09
# 1                               1.369473e+09
# 2                               1.128185e+09
# 3                               1.546956e+09
# 4                               1.298819e+09

# %% [markdown]
# ## `query__comstock_oedi__ts__by_state_time__v75`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state           timestamp  sample_count  units_count  \
# 0    CO 2018-09-12 00:45:00        134649  84415.71204
# 1    CO 2018-09-12 01:00:00        134649  84415.71204
# 2    CO 2018-09-12 01:15:00        134649  84415.71204
# 3    CO 2018-09-12 01:30:00        134649  84415.71204
# 4    CO 2018-09-12 01:45:00        134649  84415.71204
#
#    electricity.total.energy_consumption
# 0                         321435.852724
# 1                         317466.909737
# 2                         303706.205138
# 3                         300550.875612
# 4                         297504.646372

# %% [markdown]
# ## `query__comstock_oedi__ts_month__by_state_time__v76`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state  timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01        134649  84415.71204            2976
# 1    CO 2018-02-01        134649  84415.71204            2688
# 2    CO 2018-03-01        134649  84415.71204            2976
# 3    CO 2018-04-01        134649  84415.71204            2880
# 4    CO 2018-05-01        134649  84415.71204            2976
#
#    electricity.total.energy_consumption
# 0                          1.385482e+09
# 1                          1.280966e+09
# 2                          1.237644e+09
# 3                          1.171385e+09
# 4                          1.289014e+09

# %% [markdown]
# ## `query__comstock_oedi__ts_hour__by_state_time__v80`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='hour',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state           timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01 00:00:00        134649  84415.71204               4
# 1    CO 2018-01-01 01:00:00        134649  84415.71204               4
# 2    CO 2018-01-01 02:00:00        134649  84415.71204               4
# 3    CO 2018-01-01 03:00:00        134649  84415.71204               4
# 4    CO 2018-01-01 04:00:00        134649  84415.71204               4
#
#    electricity.total.energy_consumption
# 0                          2.216948e+06
# 1                          2.177930e+06
# 2                          1.874028e+06
# 3                          1.832707e+06
# 4                          1.820178e+06

# %% [markdown]
# ## `query__comstock_oedi__ts_day__by_state_time__v83`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    enduses=['out.electricity.total.energy_consumption'],
    group_by=['state', 'time'],
    restrict=[('state', ['CO'])],
    timestamp_grouping_func='day',
    upgrade_id=0,
)
result.head() if hasattr(result, 'head') else result
# Out:
# WARNING:buildstock_query.query_core:Column state found in multiple tables ['bs', 'comstock_amy2018_r2_2025_ts_by_state']. Using bs
#   state  timestamp  sample_count  units_count rows_per_sample  \
# 0    CO 2018-01-01        134649  84415.71204              96
# 1    CO 2018-01-02        134649  84415.71204              96
# 2    CO 2018-01-03        134649  84415.71204              96
# 3    CO 2018-01-04        134649  84415.71204              96
# 4    CO 2018-01-05        134649  84415.71204              96
#
#    electricity.total.energy_consumption
# 0                          5.631904e+07
# 1                          5.220220e+07
# 2                          4.810277e+07
# 3                          4.638417e+07
# 4                          4.562267e+07

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v87`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v88`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=False,
    include_savings=True,
    include_upgrade=False,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07

# %% [markdown]
# ## `query__comstock_oedi__baseline__by_comstock_building_type__v94`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.073776e+09
# 1                               7.665760e+06
# 2                               1.913053e+08
# 3                               1.654028e+08
# 4                               2.634047e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.110250e+09
# 1                               1.560906e+06
# 2                               5.037715e+07
# 3                               6.746017e+07
# 4                               2.520359e+08

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v95`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.067479e+09
# 1                               6.772289e+06
# 2                               1.684458e+08
# 3                               1.513751e+08
# 4                               2.838699e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.065733e+08
# 1                               4.943943e+04
# 2                               3.609832e+06
# 3                               1.429535e+07
# 4                               5.203942e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v96`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.110250e+09
# 1                                       1.560906e+06
# 2                                       5.037715e+07
# 3                                       6.746017e+07
# 4                                       2.520359e+08
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       9.065733e+08
# 1                                       4.943943e+04
# 2                                       3.609832e+06
# 3                                       1.429535e+07
# 4                                       5.203942e+07
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.036771e+08
# 1                                       1.511466e+06
# 2                                       4.676732e+07
# 3                                       5.316482e+07
# 4                                       1.999964e+08

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v101`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           853  1387.428142
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       1.073776e+09
# 1                                       7.665760e+06
# 2                                       1.913053e+08
# 3                                       1.654028e+08
# 4                                       2.634047e+08
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       1.067479e+09
# 1                                       6.772289e+06
# 2                                       1.684458e+08
# 3                                       1.513751e+08
# 4                                       2.838699e+08
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       6.297757e+06
# 1                                       8.934708e+05
# 2                                       2.285951e+07
# 3                                       1.402775e+07
# 4                                      -2.046520e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       1.110250e+09
# 1                                       1.560906e+06
# 2                                       5.037715e+07
# 3                                       6.746017e+07
# 4                                       2.520359e+08
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       9.065733e+08
# 1                                       4.943943e+04
# 2                                       3.609832e+06
# 3                                       1.429535e+07
# 4                                       5.203942e+07
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       2.036771e+08
# 1                                       1.511466e+06
# 2                                       4.676732e+07
# 3                                       5.316482e+07
# 4                                       1.999964e+08

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v104`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('state', ['NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant          3970  1823.927061
# 1               Hospital             5     7.105761
# 2            LargeOffice             2     8.193827
# 3           MediumOffice           347   129.419815
# 4             Outpatient           242   402.336491
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       3.835508e+08
# 1                                       7.905386e+06
# 2                                       1.058493e+06
# 3                                       4.620015e+07
# 4                                       6.485727e+07
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       3.575633e+08
# 1                                       6.587452e+06
# 2                                       8.763264e+05
# 3                                       3.834644e+07
# 4                                       5.469037e+07
#
#    electricity.total.energy_consumption..kwh__savings  \
# 0                                       2.598748e+07
# 1                                       1.317935e+06
# 2                                       1.821665e+05
# 3                                       7.853706e+06
# 4                                       1.016690e+07
#
#    natural_gas.total.energy_consumption..kwh__baseline  \
# 0                                       3.504533e+08
# 1                                       2.425941e+06
# 2                                       2.276434e+05
# 3                                       5.394055e+06
# 4                                       1.442416e+07
#
#    natural_gas.total.energy_consumption..kwh__upgrade  \
# 0                                       3.138663e+08
# 1                                       1.304981e+06
# 2                                       5.428687e+03
# 3                                       7.924080e+05
# 4                                       5.583269e+06
#
#    natural_gas.total.energy_consumption..kwh__savings
# 0                                       3.658706e+07
# 1                                       1.120960e+06
# 2                                       2.222147e+05
# 3                                       4.601647e+06
# 4                                       8.840895e+06

# %% [markdown]
# ## `query__comstock_oedi__baseline__by_state__v106`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state'],
    restrict=[('bldg_id', [51037])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  sample_count  units_count  electricity.total.energy_consumption..kwh
# 0    CO             2     0.616301                               2.545527e+05
# 1    NM            30     5.694012                               2.351817e+06
# 2    OK             1     0.043486                               1.796103e+04
# 3    TX            13     2.633057                               1.087540e+06

# %% [markdown]
# ## `query__comstock_oedi__baseline__v107`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    restrict=[('bldg_id', [51037])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count  electricity.total.energy_consumption..kwh
# 0            46     8.986855                               3.711871e+06

# %% [markdown]
# ## `query__comstock_oedi__baseline__v108`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    restrict=[('bldg_id', [51037]), ('state', ['CO'])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#    sample_count  units_count  electricity.total.energy_consumption..kwh
# 0             2     0.616301                              254552.650913

# %% [markdown]
# ## `query__comstock_oedi__baseline__by_state_in.nhgis_tract_gisjoin__v109`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state', 'in.nhgis_tract_gisjoin'],
    restrict=[('bldg_id', [51037])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state nhgis_tract_gisjoin  sample_count  units_count  \
# 0    CO      G0800710000400             1     0.107627
# 1    CO      G0800890968600             1     0.508673
# 2    NM      G3500010000115             1     0.180937
# 3    NM      G3500010000127             1     0.084652
# 4    NM      G3500010000204             1     0.161767
#
#    electricity.total.energy_consumption..kwh
# 0                               44453.541084
# 1                              210099.109829
# 2                               74732.838596
# 3                               34964.131977
# 4                               66815.019326

# %% [markdown]
# ## `query__comstock_oedi__baseline__by_state_in.county_name__v110`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state', 'in.county_name'],
    restrict=[('bldg_id', [51037])],
    upgrade_id='0',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state            county_name  sample_count  units_count  \
# 0    CO  CO, Las Animas County             1     0.107627
# 1    CO       CO, Otero County             1     0.508673
# 2    NM  NM, Bernalillo County            23     4.091421
# 3    NM      NM, Cibola County             1     0.271785
# 4    NM       NM, Curry County             3     0.541360
#
#    electricity.total.energy_consumption..kwh
# 0                               4.445354e+04
# 1                               2.100991e+05
# 2                               1.689893e+06
# 3                               1.122564e+05
# 4                               2.235998e+05

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_state__v111`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['state'],
    include_baseline=True,
    include_savings=True,
    include_upgrade=True,
    restrict=[('bldg_id', [51037])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   state  sample_count  units_count  \
# 0    CO             2     0.616301
# 1    NM            30     5.694012
# 2    OK             1     0.043486
# 3    TX            13     2.633057
#
#    electricity.total.energy_consumption..kwh__baseline  \
# 0                                       2.545527e+05
# 1                                       2.351817e+06
# 2                                       1.796103e+04
# 3                                       1.087540e+06
#
#    electricity.total.energy_consumption..kwh__upgrade  \
# 0                                       2.371935e+05
# 1                                       2.191435e+06
# 2                                       1.673618e+04
# 3                                       1.013376e+06
#
#    electricity.total.energy_consumption..kwh__savings
# 0                                       17359.130822
# 1                                      160381.343440
# 2                                        1224.846063
# 3                                       74164.429092

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v121`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    46403         G0800490000205    CO
# 1    48235         G0800490000202    CO
# 2    48340         G0800490000206    CO
# 3    48345         G0800490000207    CO
# 4    48346         G0800490000203    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v122`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    51068         G0800890968100    CO
# 1    51072         G0800890968600    CO
# 2    51384         G0800890968600    CO
# 3    51670         G0800890968300    CO
# 4    51772         G0800890968400    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v123`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    48662         G0800050005631    CO
# 1    48667         G0800050006712    CO
# 2    48667         G0800050007101    CO
# 3    48669         G0800050005700    CO
# 4    48669         G0800050007107    CO

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v124`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         12018  4222.612917
# 1            LargeOffice            25     8.927070
# 2           MediumOffice          1823   603.917258
# 3             Outpatient           839  1378.302123
# 4          PrimarySchool           912  1108.926331
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.067479e+09
# 1                               6.772289e+06
# 2                               1.684458e+08
# 3                               1.456331e+08
# 4                               2.838699e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               9.065733e+08
# 1                               4.943943e+04
# 2                               3.609832e+06
# 3                               1.386505e+07
# 4                               5.203942e+07

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v125`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    48235         G0800230972700    CO
# 1    48346         G0800230972700    CO
# 2    48364         G0800230972600    CO
# 3    51061         G3500610970800    NM
# 4    51066         G3500610970405    NM

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v126`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[2]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    48685         G0800550960600    CO
# 1    48696         G0800550960901    CO
# 2    50083         G0800550960600    CO
# 3    50163         G0800550960902    CO
# 4    50169         G0800550960600    CO

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v127`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    50166         G0800470013802    CO
# 1    46398         G0800370000503    CO
# 2    46403         G0800370000703    CO
# 3    46429         G0800370000401    CO
# 4    46484         G0800370000403    CO

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v128`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         15988  6046.539978
# 1               Hospital             5     7.105761
# 2            LargeOffice            27    17.120897
# 3           MediumOffice          2170   733.337073
# 4             Outpatient          1081  1780.638615
#
#    electricity.total.energy_consumption..kwh  \
# 0                               1.425042e+09
# 1                               6.587452e+06
# 2                               7.648615e+06
# 3                               2.067922e+08
# 4                               2.003235e+08
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.220440e+09
# 1                               1.304981e+06
# 2                               5.486811e+04
# 3                               4.402240e+06
# 4                               1.944832e+07

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v129`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['NM'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    11627         G3500390000500    NM
# 1    12792         G3500390000300    NM
# 2    12979         G3500390000301    NM
# 3    13058         G3500390940700    NM
# 4    13065         G3500390000200    NM

# %% [markdown]
# ## `get_building_ids__comstock_oedi__v140`
#
# Auto-recorded from test_invariants (get_building_ids, comstock_oedi).

# %%
result = bsq.get_building_ids(restrict=[('state', ['CO'])])
result.head() if hasattr(result, 'head') else result
# Out:
#    bldg_id in.nhgis_tract_gisjoin state
# 0    48690         G0800590011552    CO
# 1    48690         G0800590009845    CO
# 2    48690         G0800590011402    CO
# 3    48690         G0800590010100    CO
# 4    48690         G0800590012027    CO

# %% [markdown]
# ## `query__comstock_oedi__by_comstock_building_type__v143`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.natural_gas.total.energy_consumption..kwh'],
    get_nonzero_count=True,
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         13461  4556.431396
# 1               Hospital            73   152.003100
# 2             LargeHotel          2815  3317.336942
# 3            LargeOffice          2271   849.927533
# 4           MediumOffice          8708  2418.404703
#
#    natural_gas.total.energy_consumption..kwh  \
# 0                               1.192192e+09
# 1                               7.929358e+08
# 2                               9.199770e+08
# 3                               4.447000e+08
# 4                               4.000924e+08
#
#    natural_gas.total.energy_consumption..kwh__nonzero_units_count
# 0                                        4556.431396
# 1                                         152.003100
# 2                                        3317.336942
# 3                                         593.598590
# 4                                        1873.838356

# %% [markdown]
# ## `query__comstock_oedi__by_vintage__v146`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['vintage'],
    limit=5,
    restrict=[('state', ['CO'])],
    sort=True,
)
result.head() if hasattr(result, 'head') else result
# Out:
#         vintage  sample_count   units_count  \
# 0  1946 to 1959         15416  11466.085224
# 1  1960 to 1969         10553   5032.258720
# 2  1970 to 1979         22004  16714.165078
# 3  1980 to 1989         21085  11994.992091
# 4  1990 to 1999         16616   9542.647650
#
#    electricity.total.energy_consumption..kwh
# 0                               1.414138e+09
# 1                               1.407104e+09
# 2                               2.386718e+09
# 3                               2.733411e+09
# 4                               2.119967e+09

# %% [markdown]
# ## `query__comstock_oedi__by_comstock_building_type__v149`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    agg_func='mean',
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  \
# 0  FullServiceRestaurant         13461  4556.431396
# 1               Hospital            73   152.003100
# 2             LargeHotel          2815  3317.336942
# 3            LargeOffice          2271   849.927533
# 4           MediumOffice          8708  2418.404703
#
#    electricity.total.energy_consumption..kwh__mean
# 0                                     3.423717e+05
# 1                                     8.748730e+06
# 2                                     1.206118e+06
# 3                                     2.813063e+06
# 4                                     6.678024e+05

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_comstock_building_type__v151`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         12018  4222.612917           35040
# 1            LargeOffice            25     8.927070           35040
# 2           MediumOffice          1823   603.917258           35040
# 3             Outpatient           839  1378.302123           35040
# 4          PrimarySchool           912  1108.926331           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          1.067478e+09                          9.071796e+08
# 1                          6.772292e+06                          4.947173e+04
# 2                          1.684457e+08                          3.612400e+06
# 3                          1.456332e+08                          1.387436e+07
# 4                          2.838701e+08                          5.207440e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_comstock_building_type_time__v152`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['comstock_building_type', 'time'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         12018  4222.612917
# 1  FullServiceRestaurant 2018-02-01         12018  4222.612917
# 2  FullServiceRestaurant 2018-03-01         12018  4222.612917
# 3  FullServiceRestaurant 2018-04-01         12018  4222.612917
# 4  FullServiceRestaurant 2018-05-01         12018  4222.612917
#
#   rows_per_sample  electricity.total.energy_consumption  \
# 0            2976                          1.041671e+08
# 1            2688                          1.016340e+08
# 2            2976                          8.463370e+07
# 3            2880                          7.864523e+07
# 4            2976                          8.022208e+07
#
#    natural_gas.total.energy_consumption
# 0                          8.183587e+07
# 1                          7.482833e+07
# 2                          7.862536e+07
# 3                          7.464483e+07
# 4                          7.459019e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_county__v153`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption..kwh', 'out.natural_gas.total.energy_consumption..kwh'],
    group_by=['county'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  sample_count  units_count  \
# 0  G0800010          5948  4804.637602
# 1  G0800030           259   139.689194
# 2  G0800050          7434  4862.682818
# 3  G0800070           205    95.758184
# 4  G0800090            41    15.683240
#
#    electricity.total.energy_consumption..kwh  \
# 0                               6.858618e+08
# 1                               1.195576e+07
# 2                               5.657102e+08
# 3                               8.205993e+06
# 4                               1.572804e+06
#
#    natural_gas.total.energy_consumption..kwh
# 0                               1.323744e+08
# 1                               3.039211e+06
# 2                               1.472686e+08
# 3                               2.562789e+06
# 4                               3.176032e+05

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_county__v154`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['county'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  sample_count  units_count rows_per_sample  \
# 0  G0800010          5948  4804.637602           35040
# 1  G0800030           259   139.689194           35040
# 2  G0800050          7434  4862.682818           35040
# 3  G0800070           205    95.758184           35040
# 4  G0800090            41    15.683240           35040
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          6.858619e+08                          1.324627e+08
# 1                          1.195578e+07                          3.041263e+06
# 2                          5.657102e+08                          1.473664e+08
# 3                          8.206003e+06                          2.564515e+06
# 4                          1.572810e+06                          3.178172e+05

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_county_time__v155`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=['out.electricity.total.energy_consumption', 'out.natural_gas.total.energy_consumption'],
    group_by=['county', 'time'],
    restrict=[bsq.get_applied_buildings_filter(all_of=[1, 2]), ('state', ['CO'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#      county  timestamp  sample_count  units_count rows_per_sample  \
# 0  G0800010 2018-01-01          5948  4804.637602            2976
# 1  G0800010 2018-02-01          5948  4804.637602            2688
# 2  G0800010 2018-03-01          5948  4804.637602            2976
# 3  G0800010 2018-04-01          5948  4804.637602            2880
# 4  G0800010 2018-05-01          5948  4804.637602            2976
#
#    electricity.total.energy_consumption  natural_gas.total.energy_consumption
# 0                          7.060403e+07                          1.657152e+07
# 1                          7.149407e+07                          1.806266e+07
# 2                          5.379953e+07                          1.044328e+07
# 3                          4.894908e+07                          9.480886e+06
# 4                          4.882248e+07                          8.549346e+06

# %% [markdown]
# ## `query__comstock_oedi__u1__by_comstock_building_type__v167`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption..kwh - out.natural_gas.total.energy_consumption..kwh', table='baseline')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  elec_minus_gas
# 0  FullServiceRestaurant         17761  6481.401989    2.673392e+08
# 1               Hospital           175   384.224912    8.004801e+08
# 2             LargeHotel          3562  3836.361595    2.755110e+08
# 3            LargeOffice          2444   920.591301    1.171844e+09
# 4           MediumOffice         10251  2903.093740    1.110408e+09

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_year__by_comstock_building_type__v168`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         17761  6481.401989           35040
# 1               Hospital           175   384.224912           35040
# 2             LargeHotel          3562  3836.361595           35040
# 3            LargeOffice          2444   920.591301           35040
# 4           MediumOffice         10251  2903.093740           35040
#
#    elec_minus_gas
# 0    2.664527e+08
# 1    7.996552e+08
# 2    2.747804e+08
# 3    1.171530e+09
# 4    1.110143e+09

# %% [markdown]
# ## `query__comstock_oedi__u1__ts_month__by_comstock_building_type_time__v169`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=False,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         17761  6481.401989
# 1  FullServiceRestaurant 2018-02-01         17761  6481.401989
# 2  FullServiceRestaurant 2018-03-01         17761  6481.401989
# 3  FullServiceRestaurant 2018-04-01         17761  6481.401989
# 4  FullServiceRestaurant 2018-05-01         17761  6481.401989
#
#   rows_per_sample  elec_minus_gas
# 0            2976    2.982614e+07
# 1            2688    3.250791e+07
# 2            2976    1.063463e+07
# 3            2880    9.450730e+06
# 4            2976    1.595577e+07

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__by_comstock_building_type__v170`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption..kwh - out.natural_gas.total.energy_consumption..kwh', table='baseline')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count  elec_minus_gas
# 0  FullServiceRestaurant         15988  6046.539978    2.046022e+08
# 1               Hospital             5     7.105761    5.282471e+06
# 2            LargeOffice            27    17.120897    7.593747e+06
# 3           MediumOffice          2170   733.337073    2.023900e+08
# 4             Outpatient          1095  1789.764634    1.861868e+08

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_year__by_comstock_building_type__v171`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='year',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  sample_count  units_count rows_per_sample  \
# 0  FullServiceRestaurant         15988  6046.539978           35040
# 1               Hospital             5     7.105761           35040
# 2            LargeOffice            27    17.120897           35040
# 3           MediumOffice          2170   733.337073           35040
# 4             Outpatient          1095  1789.764634           35040
#
#    elec_minus_gas
# 0    2.037852e+08
# 1    5.281589e+06
# 2    7.593703e+06
# 3    2.023868e+08
# 4    1.861737e+08

# %% [markdown]
# ## `query__comstock_oedi__applied__u1__ts_month__by_comstock_building_type_time__v172`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    annual_only=False,
    applied_only=True,
    enduses=[bsq.get_calculated_column('elec_minus_gas', 'out.electricity.total.energy_consumption - out.natural_gas.total.energy_consumption', table='timeseries')],
    group_by=['comstock_building_type', 'time'],
    restrict=[('state', ['CO', 'NM'])],
    timestamp_grouping_func='month',
    upgrade_id='1',
)
result.head() if hasattr(result, 'head') else result
# Out:
#   comstock_building_type  timestamp  sample_count  units_count  \
# 0  FullServiceRestaurant 2018-01-01         15988  6046.539978
# 1  FullServiceRestaurant 2018-02-01         15988  6046.539978
# 2  FullServiceRestaurant 2018-03-01         15988  6046.539978
# 3  FullServiceRestaurant 2018-04-01         15988  6046.539978
# 4  FullServiceRestaurant 2018-05-01         15988  6046.539978
#
#   rows_per_sample  elec_minus_gas
# 0            2976    2.479894e+07
# 1            2688    2.795347e+07
# 2            2976    6.530650e+06
# 3            2880    5.293182e+06
# 4            2976    1.061216e+07

# %% [markdown]
# ## `query__comstock_oedi__v180`
#
# Auto-recorded from test_invariants (query, comstock_oedi).

# %%
result = bsq.query(
    enduses=['out.electricity.total.energy_consumption..kwh'],
    group_by=[MappedColumn(bsq=bsq, name='simple_bldg_type', mapping_dict={'FullServiceRestaurant': 'Food', 'Hospital': 'Health', 'LargeHotel': 'Lodging', 'LargeOffice': 'Office', 'MediumOffice': 'Office', 'Outpatient': 'Health', 'PrimarySchool': 'School', 'QuickServiceRestaurant': 'Food', 'RetailStandalone': 'Retail', 'RetailStripmall': 'Retail', 'SecondarySchool': 'School', 'SmallHotel': 'Lodging', 'SmallOffice': 'Office', 'Warehouse': 'Warehouse'}, key=bsq._get_column('comstock_building_type'))],
    restrict=[('state', ['CO'])],
)
result.head() if hasattr(result, 'head') else result
# Out:
#   simple_bldg_type  sample_count   units_count  \
# 0             Food         20015   6735.091005
# 1           Health          1420   2089.226424
# 2          Lodging          5608   4548.531762
# 3           Office         39576  22514.402048
# 4           Retail         44707  21431.873432
#
#    electricity.total.energy_consumption..kwh
# 0                               1.540008e+09
# 1                               1.990316e+09
# 2                               1.382815e+09
# 3                               3.921176e+09
# 4                               2.990783e+09
